# %%
# !pip install backtrader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: backtrader in c:\users\user\appdata\roaming\python\python311\site-packages (1.9.78.123)

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import scipy.stats as st

import backtrader as bt
import backtrader.feeds as btfeeds
import backtrader.indicators as btind
import backtrader.analyzers as btanalyzers

import math
import datetime
import pytz

# from ipynb.fs.full.Task1 import get_files
# from ipynb.fs.full.Task2 import find_suitable_pairs
from BackTrader import *
# from BackTrader import PandasData, PairTradingStrategy
# from BackTrader import CommInfoFloat, DataAnalyzer, CashValueAnalyzer, OrderAnalyzer

# %%
# import backtrader as bt
import backtrader.feeds as btfeeds
import backtrader.indicators as btind
import backtrader.analyzers as btanalyzers
from enum import Enum
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib

import math
import datetime

#This is the data feed to be fed into the backtesting lib
class PandasData(btfeeds.PandasData):
    params = (
        # Possible values for datetime (must always be present)
        #  None : datetime is the "index" in the Pandas Dataframe
        #  -1 : autodetect position or case-wise equal name
        #  >= 0 : numeric index to the colum in the pandas dataframe
        #  string : column name (as index) in the pandas dataframe
        ('datetime', None),

        ('open', 'Open'),
        ('high', 'High'),
        ('low', 'Low'),
        ('close', 'Adj Close'),
        ('openinterest', None),
    )
    
class Log(btind.Indicator):
    """Calculates log."""
    lines = ('log',)
    
    def next(self):
        self.l.log[0] = math.log(self.data[0])

class OLSSlopeIntercept(btind.PeriodN):
    """Calculates a linear regression using OLS."""
    _mindatas = 2  # ensure at least 2 data feeds are passed

    lines = ('slope', 'intercept',)
    params = (
        ('period', 10),
    )

    def next(self):
        p0 = pd.Series(self.data0.get(size=self.p.period))
        p1 = pd.Series(self.data1.get(size=self.p.period))
        p1 = sm.add_constant(p1)
        intercept, slope = sm.OLS(p0, p1).fit().params

        self.lines.slope[0] = slope
        self.lines.intercept[0] = intercept

class OLSSpread(btind.PeriodN):
    """Calculates the z-score of the OLS spread."""
    _mindatas = 2  # ensure at least 2 data feeds are passed
    lines = ('slope', 'spread', 'spread_mean', 'spread_std', 'zscore',)
    params = (('period', 10),)

    def __init__(self):
        data0_log = Log(self.data0)
        data1_log = Log(self.data1)
        slint = OLSSlopeIntercept(data0_log, data1_log, period=self.p.period)

        spread = data0_log - (slint.slope * data1_log + slint.intercept)
        self.l.spread = spread
        self.l.slope = slint.slope

        self.l.spread_mean = bt.ind.SMA(spread, period=self.p.period)
        self.l.spread_std = bt.ind.StdDev(spread, period=self.p.period)
        self.l.zscore = (spread - self.l.spread_mean) / self.l.spread_std
        
class Status(Enum):
    LONG = 1
    SHORT = 2
    NONE = 3
    
class PairTradingStrategy(bt.Strategy):
    """Basic pair trading strategy."""
    
    # These are just default values, pass in these values while initialising strategy
    params = dict(
        period=100,
        order_pct1=0.1,
        order_pct2=0.1,
        printout=True,
        upper=2,
        lower=2,
        symbol1="SYMBOL1",
        symbol2="SYMBOL2"
    )

    def log(self, txt, dt=None):
        if self.p.printout:
            dt = dt or self.data.datetime[0]
            dt = bt.num2date(dt)
            print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [bt.Order.Submitted, bt.Order.Accepted]:
            return  # Await further notifications

        if order.status == order.Completed:
            if order.isbuy():
                buytxt = 'BUY COMPLETE {}, size = {:.2f}, price = {:.2f}'.format(
                    order.data._name, order.executed.size, order.executed.price)
                self.log(buytxt, order.executed.dt)
            else:
                selltxt = 'SELL COMPLETE {}, size = {:.2f}, price = {:.2f}'.format(
                    order.data._name, order.executed.size, order.executed.price)
                self.log(selltxt, order.executed.dt)

        elif order.status in [order.Expired, order.Canceled, order.Margin]:
            self.log('%s ,' % order.Status[order.status])
            pass  # Simply log

        # Allow new orders
        self.orderid = None

    def __init__(self):
        # To control operation entries
        self.orderid = None
        self.order_pct1 = self.p.order_pct1
        self.order_pct2 = self.p.order_pct2
        self.upper = self.p.upper
        self.lower = self.p.lower
        
        self.transform = OLSSpread(self.data0, self.data1, period=self.p.period)

        self.spread = self.transform.spread
        self.zscore = self.transform.zscore
        self.slope = self.transform.slope
        
        self.status = Status.NONE
        self.symbol1 = self.p.symbol1
        self.symbol2 = self.p.symbol2

    def next(self):
        if self.orderid:
            return  # if an order is active, no new orders are allowed
        
        if self.zscore[0] > self.upper and self.status != Status.SHORT:
            # Short sell stock 1
            self.order_target_percent(data=self.data0, target=-self.order_pct1)
            # Buy stock 2
            self.order_target_percent(data=self.data1, target=self.order_pct2)
            
            self.status = Status.SHORT

        elif self.zscore[0] < self.lower and self.status != Status.LONG:
            # Short sell stock 2
            self.order_target_percent(data=self.data1, target=-self.order_pct2)
            # Buy stock 1
            self.order_target_percent(data=self.data0, target=self.order_pct1)
                     
            self.status = Status.LONG
        
#         # Sample strategy does not close position when zscore reaches zero again, 
#         # only reverses position when it swings the other way
#         # uncomment below if desired behaviour is to close at z-score = 0
#         elif self.zscore[0] <= 0 and self.status == Status.SHORT:
#             # Close position
#             self.order_target_percent(data=self.data1, target=0)
#             self.order_target_percent(data=self.data0, target=0)
#             self.status = Status.NONE
        
#         elif self.zscore[0] >= 0 and self.status == Status.LONG:
#             # Close position
#             self.order_target_percent(data=self.data1, target=0)
#             self.order_target_percent(data=self.data0, target=0)
#             self.status = Status.NONE

    def stop(self):
        if self.p.printout:
            print('==================================================')
            print('Starting Value - %.2f' % self.broker.startingcash)
            print('Ending   Value - %.2f' % self.broker.getvalue())
            print('==================================================')


# This this can be added to Cerebro allow fractional shares (for this like crypto)
# By default backtrader doesnt allow that.
class CommInfoFloat(bt.CommInfoBase):
    """Commission schema that keeps size as float."""
    params = (
        ('stocklike', True),
        ('commtype', bt.CommInfoBase.COMM_PERC),
        ('percabs', True),
      )
    
    def getsize(self, price, cash):
        if not self._stocklike:
            return self.p.leverage * (cash / self.get_margin(price))

        return self.p.leverage * (cash / price)


class DataAnalyzer(bt.analyzers.Analyzer):
    """Analyzer to extract OHLCV."""
    def create_analysis(self):
        self.rets0 = {}
        self.rets1 = {}

    def next(self):
        self.rets0[self.strategy.datetime.datetime()] = [
            self.data0.open[0],
            self.data0.high[0],
            self.data0.low[0],
            self.data0.close[0],
            self.data0.volume[0]
        ]
        self.rets1[self.strategy.datetime.datetime()] = [
            self.data1.open[0],
            self.data1.high[0],
            self.data1.low[0],
            self.data1.close[0],
            self.data1.volume[0]
        ]

    def get_analysis(self):
        return self.rets0, self.rets1

class CashValueAnalyzer(bt.analyzers.Analyzer):
    """Analyzer to extract cash and value."""
    def create_analysis(self):
        self.rets = {}

    def notify_cashvalue(self, cash, value):
        self.rets[self.strategy.datetime.datetime()] = self.strategy.broker.getvalue()

    def get_analysis(self):
        return self.rets
    
class OrderAnalyzer(bt.analyzers.Analyzer):
    """Analyzer to extract order price, size, value, and paid commission."""
    def create_analysis(self):
        self.rets0 = {}
        self.rets1 = {}

    def notify_order(self, order):
        if order.status == order.Completed:
            if order.data._name == self.strategy.symbol1:
                rets = self.rets0
            else:
                rets = self.rets1
            rets[self.strategy.datetime.datetime()] = (
                order.executed.price,
                order.executed.size,
                -order.executed.size * order.executed.price,
                order.executed.comm
            )

    def get_analysis(self):
        return self.rets0, self.rets1

# %%
def calculate_volatility(values):
    values = pd.Series(values)
    log_return = np.log(values/values.shift())
    volatility = log_return.std()*252**.5
    return volatility*100

# %%
start_date = '2015-01-01'
end_date = '2023-01-01'

# %%
import yfinance as yf
CSI300 = yf.download("000300.SS", start=start_date, end=end_date)
CSI300 = CSI300.drop(columns=['Volume'])
CSI300
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close
# Date
# 2021-03-11  5024.560059  5138.410156  5020.580078  5128.220215  5128.220215
# 2021-03-12  5153.669922  5153.669922  5086.819824  5146.379883  5146.379883
# 2021-03-15  5116.120117  5120.879883  4992.399902  5035.540039  5035.540039
# 2021-03-16  5054.410156  5084.310059  5009.950195  5079.359863  5079.359863
# 2021-03-17  5062.770020  5123.549805  5020.129883  5100.859863  5100.859863
# ...                 ...          ...          ...          ...          ...
# 2022-12-26  3830.570068  3856.810059  3827.520020  3843.489990  3843.489990
# 2022-12-27  3860.909912  3891.850098  3856.580078  3887.850098  3887.850098
# 2022-12-28  3874.909912  3884.719971  3854.939941  3871.260010  3871.260010
# 2022-12-29  3854.239990  3868.290039  3838.479980  3856.699951  3856.699951
# 2022-12-30  3873.939941  3887.550049  3868.760010  3871.629883  3871.629883
#
# [442 rows x 5 columns]

# %%
class BuyAndHold(bt.Strategy):
    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def nextstart(self):
        # Buy all the available cash
        self.order_target_value(target=self.broker.get_cash())

    def stop(self):
        pass
#         # calculate the actual returns
#         self.roi = (self.broker.get_value() / self.val_start) - 1.0
#         print('ROI:        {:.2f}%'.format(100.0 * self.roi))

# %%
cerebro = bt.Cerebro()
csi300_datafeed = PandasData(dataname=CSI300, name="CSI300")
cerebro.adddata(csi300_datafeed)
cerebro.addstrategy(BuyAndHold)
cerebro.addanalyzer(btanalyzers.DrawDown, _name='drawdown')
cerebro.addanalyzer(btanalyzers.SharpeRatio_A, _name='sharpe')
cerebro.addanalyzer(btanalyzers.Returns, _name='returns')
cerebro.broker.setcash(100000)
res = cerebro.run()[0]
print("Sharpe Ratio: ", res.analyzers.sharpe.get_analysis()["sharperatio"])
print("Annualised Return: ", res.analyzers.returns.get_analysis()["rnorm100"])
print("Max Drawdown: ", res.analyzers.drawdown.get_analysis()["max"]["drawdown"])
print("Annualised Volatilty: ", calculate_volatility(CSI300["Close"]))
# print()
# pairs.at[indexes[index], "SharpeRatio"] = res.analyzers.sharpe.get_analysis()["sharperatio"]
#         pairs.at[indexes[index], "Annualised Return(%)"] = res.analyzers.returns.get_analysis()["rnorm100"]
#         pairs.at[indexes[index], "Max Drawdown(%)"] = res.analyzers.drawdown.get_analysis()["max"]["drawdown"]
#         pairs.at[indexes[index], "Annualised Volatility(%)"] = volatility
# Out:
# Sharpe Ratio:  -1.5905762618206447
# Annualised Return:  -14.714349933850542
# Max Drawdown:  33.62545741806995
# Annualised Volatilty:  18.71546363098488

# %%
PRICE_DIR = "individual_data"
STOCK_PRICE = {}

# %%
# Adjust these params for backtesting
PARAMS = {
    "CASH" : 100000,
    "UPPER" : st.norm.ppf(1 - 0.05 / 2),
    "LOWER" : -st.norm.ppf(1 - 0.05 / 2),
    "ORDER_PCT1" : 0.5, # Essentially order size (how much pct of current portfolio you want to spend for stock)
    "ORDER_PCT2" : 0.5,
    "PERIOD" : 100, # Look back period for doing rolling OLS and z-score calc.
    "COMMPERC": 0.005 # 0.5%
}

def run_backtest(stock1_name, stock2_name, stock1_df, stock2_df, PARAMS):
    stock1_datafeed = PandasData(dataname=stock1_df, name=stock1_name)
    stock2_datafeed = PandasData(dataname=stock2_df, name=stock2_name)

    
    cerebro = bt.Cerebro()

    cerebro.adddata(stock1_datafeed)
    cerebro.adddata(stock2_datafeed)

    cerebro.addstrategy(PairTradingStrategy, 
                        period=PARAMS["PERIOD"], 
                        upper=PARAMS["UPPER"], 
                        lower=PARAMS["LOWER"], 
                        order_pct1=PARAMS["ORDER_PCT1"],
                        order_pct2=PARAMS["ORDER_PCT2"],
                        symbol1=stock1_name,
                        symbol2=stock2_name,
                        printout=False)

    cerebro.addanalyzer(btanalyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(btanalyzers.SharpeRatio_A, _name='sharpe')
    cerebro.addanalyzer(btanalyzers.TradeAnalyzer, _name='ta')
    cerebro.addanalyzer(btanalyzers.Returns, _name='returns')
#     cerebro.addanalyzer(btanalyzers.LogReturnsRolling, _name='logrollingreturns')
    cerebro.addanalyzer(btanalyzers.AnnualReturn, _name='annualreturn')
#     cerebro.addanalyzer(btanalyzers.PositionsValue, _name='positionvalues')
    
    # Below are custom analyzers defined by the sample code, can uncomment if you need more detailed info
    cerebro.addanalyzer(DataAnalyzer)
    cerebro.addanalyzer(CashValueAnalyzer)
    cerebro.addanalyzer(OrderAnalyzer)

    cerebro.broker.setcash(PARAMS["CASH"])
    comminfo = CommInfoFloat(commission=PARAMS["COMMPERC"])
    cerebro.broker.addcommissioninfo(comminfo)

    backtest_res = cerebro.run()[0]
    return backtest_res

# %%
filtered_pairs = pd.read_pickle("Data/filtered_pairs_dict.pickle")

# %%
filtered_pairs
# Out:
# {'KMeans':                                                    pair        pvalue  \
#  0     (Communication Services-Communication Services...  1.024104e-03
#  2     (Communication Services-Communication Services...  1.370479e-05
#  5     (Healthcare-Healthcare - 300142.SZ.csv, Health...  2.835066e-02
#  6     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  1.871553e-02
#  7     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  2.565211e-02
#  ...                                                 ...           ...
#  3310  (Industry-Industry - 002709.SZ.csv, Industry-I...  0.000000e+00
#  3314  (Industry-Industry - 300014.SZ.csv, Industry-I...  0.000000e+00
#  3315  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
#  3316  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
#  3317  (Industry-Industry - 600884.SH.csv, Materials-...  1.813381e-29
#
#        hurst_exp   half_life  avg_cross_count
#  0      0.045492    1.693115       111.770021
#  2      0.028210    2.532232       111.252567
#  5      0.066402    4.820998        96.936345
#  6      0.028967    8.024377       103.663244
#  7      0.097647    8.811799       106.595483
#  ...         ...         ...              ...
#  3310   0.000400  157.778025       128.845996
#  3314   0.005210   11.634979       126.776181
#  3315   0.007635   51.272003       124.188912
#  3316   0.006595   59.069991       119.531828
#  3317   0.003271   15.703670       129.363450
#
#  [1815 rows x 5 columns],
#  'Agglo':                                                  pair    pvalue  hurst_exp  \
#  0   (Communication Services-Communication Services...  0.006741   0.053243
#  1   (Communication Services-Communication Services...  0.032566   0.054124
#  2   (Communication Services-Communication Services...  0.003626   0.057317
#  3   (Communication Services-Communication Services...  0.002735   0.053958
#  4   (Communication Services-Communication Services...  0.002167   0.055102
#  ..                                                ...       ...        ...
#  67  (Communication Services-Communication Services...  0.002896   0.055350
#  68  (Communication Services-Communication Services...  0.002647   0.053475
#  70  (Communication Services-Communication Services...  0.002485   0.053928
#  71  (Communication Services-Communication Services...  0.001743   0.052262
#  72  (Communication Services-Communication Services...  0.002756   0.055481
#
#      half_life  avg_cross_count
#  0   57.754258       110.045175
#  1   57.083765       109.527721
#  2   57.302884       111.080082
#  3   57.535480       112.114990
#  4   57.562617       107.285421
#  ..        ...              ...
#  67  57.595307       110.390144
#  68  57.863895       110.390144
#  70  57.784840       113.494867
#  71  57.998827       109.355236
#  72  57.688107       112.459959
#
#  [69 rows x 5 columns],
#  'DBSCAN':                                                   pair        pvalue  \
#  0    (Communication Services-Communication Services...  1.283926e-17
#  5    (Communication Services-Communication Services...  3.241014e-18
#  9    (Communication Services-Communication Services...  0.000000e+00
#  23   (Communication Services-Communication Services...  2.651843e-11
#  28   (Communication Services-Communication Services...  1.627593e-18
#  ..                                                 ...           ...
#  337  (Communication Services-Communication Services...  1.832293e-23
#  339  (Communication Services-Communication Services...  1.423910e-19
#  341  (Communication Services-Communication Services...  0.000000e+00
#  342  (Communication Services-Communication Services...  1.677731e-17
#  350  (Communication Services-Communication Services...  2.620260e-17
#
#       hurst_exp   half_life  avg_cross_count
#  0     0.001681   58.658545       119.704312
#  5     0.006920  215.050697       132.985626
#  9    -0.007808  245.102818       122.119097
#  23   -0.000664  249.534483       124.878850
#  28   -0.002497  231.619843       127.638604
#  ..         ...         ...              ...
#  337   0.002654   80.990246       120.911704
#  339   0.003709   77.639329       119.014374
#  341   0.000858   82.353605       122.981520
#  342   0.002548   84.999596       122.809035
#  350   0.000470   80.265233       122.464066
#
#  [165 rows x 5 columns]}

# %%
start_test = '2021-01-01'
end_test = '2022-12-30'

# %%
from datetime import datetime

# %%
TESTING_START = datetime(2021, 1, 1)
TESTING_END = datetime(2022, 12, 30)
backtest_results_raw = {}

# %%
STOCK_PRICE = {}

# %%
def read_stock_price(stock_name):
    stock_name = stock_name.replace("-", "/", 1)
    if stock_name in STOCK_PRICE:
        return STOCK_PRICE[stock_name]
    file_path = PRICE_DIR + "/" + stock_name
    df = pd.read_csv(file_path)
    df = df.drop(0)
    df = df.ffill()
    dates = pd.to_datetime(df['Date'], format="%Y%m%d", utc=True)
    dates = dates.dt.strftime("%Y-%m-%d")
    df['Date'] = dates
    dates = pd.to_datetime(dates)
    
#     print(dates)
#     print(df['Date'])
    df.index = dates
    df = df.loc[df.index >= TESTING_START]
    df = df.loc[df.index <= TESTING_END]
    STOCK_PRICE[stock_name] = df
    
    df.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'adj close': 'Adj Close', 'vol': 'Volume'}, inplace=True)
    df = df[['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Returns']]
    return df

# %%
for pair_strat, pairs in filtered_pairs.items():
    print("Doing Backtesting for ", pair_strat)
    pairs["SharpeRatio"] = np.nan
    pairs["Annualised Return(%)"] = np.nan
    pairs["Max Drawdown(%)"] = np.nan
    pairs["Annualised Volatility(%)"] = np.nan
    raw_results = {}
    indexes = pairs.index
    for (index, (stock1, stock2)) in enumerate(pairs["pair"]):
        print("Backtesting for ", (stock1, stock2))
        stock1_df = read_stock_price(stock1)
        stock2_df = read_stock_price(stock2)
        if stock1_df.isnull().values.any() or stock2_df.isnull().values.any():
            print(f'{stock1} or {stock2} has null values')
            continue
        try:
            res = run_backtest(stock1, stock2, stock1_df, stock2_df, PARAMS)
        except IndexError:
            print('Index Error')
        portfolio_value = res.analyzers.cashvalueanalyzer.get_analysis()
        volatility = calculate_volatility(portfolio_value.values())
        orders = res.analyzers.orderanalyzer.get_analysis()
        
        # Raw results store the portfolio value at each date, and also the specific orders which were made during backtesting
        raw_results[(stock1, stock2)] = (portfolio_value, orders)        
        print(res.analyzers.sharpe.get_analysis())
        break
        pairs.at[indexes[index], "SharpeRatio"] = res.analyzers.sharpe.get_analysis()["sharperatio"]
        pairs.at[indexes[index], "Annualised Return(%)"] = res.analyzers.returns.get_analysis()["rnorm100"]
        pairs.at[indexes[index], "Max Drawdown(%)"] = res.analyzers.drawdown.get_analysis()["max"]["drawdown"]
        pairs.at[indexes[index], "Annualised Volatility(%)"] = volatility
#     backtest_results_raw[pair_strat] = raw_results
# Out:
# Doing Backtesting for  KMeans
# Backtesting for  ('Communication Services-Communication Services - 002027.SZ.csv', 'Communication Services-Communication Services - 002555.SZ.csv')
# <__main__.PairTradingStrategy object at 0x0000014AA9463350>
# OrderedDict([('sharperatio', None)])
# Doing Backtesting for  Agglo
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Communication Services-Communication Services - 002555.SZ.csv')
# <__main__.PairTradingStrategy object at 0x0000014AAAD8F650>
# OrderedDict([('sharperatio', None)])
# Doing Backtesting for  DBSCAN
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Communication Services-Communication Services - 300628.SZ.csv')
# <__main__.PairTradingStrategy object at 0x0000014AA982C4D0>
# OrderedDict([('sharperatio', None)])

# %%
raw_results
# Out:
# {('Communication Services-Communication Services - 000063.SZ.csv',
#   'Communication Services-Communication Services - 300628.SZ.csv'): ({datetime.datetime(2023, 1, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 4, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 5, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 9, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 11, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 12, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 16, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 18, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 19, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 30, 0, 0): 100000.0,
#    datetime.datetime(2023, 1, 31, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 1, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 2, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 8, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 9, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 14, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 15, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 16, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 21, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 22, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 23, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 24, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 27, 0, 0): 100000.0,
#    datetime.datetime(2023, 2, 28, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 1, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 2, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 8, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 9, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 14, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 15, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 16, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 21, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 22, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 23, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 24, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 27, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 28, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 29, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 30, 0, 0): 100000.0,
#    datetime.datetime(2023, 3, 31, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 4, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 11, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 12, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 14, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 18, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 19, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 21, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 24, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 25, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 26, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 27, 0, 0): 100000.0,
#    datetime.datetime(2023, 4, 28, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 4, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 5, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 8, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 9, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 11, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 12, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 15, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 16, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 18, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 19, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 22, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 23, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 24, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 25, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 26, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 29, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 30, 0, 0): 100000.0,
#    datetime.datetime(2023, 5, 31, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 1, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 2, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 5, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 8, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 9, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 12, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 14, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 15, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 16, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 19, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 21, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 26, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 27, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 28, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 29, 0, 0): 100000.0,
#    datetime.datetime(2023, 6, 30, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 4, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 5, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 6, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 10, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 11, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 12, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 13, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 14, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 17, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 18, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 19, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 20, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 21, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 24, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 25, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 26, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 27, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 28, 0, 0): 100000.0,
#    datetime.datetime(2023, 7, 31, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 1, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 2, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 3, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 4, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 7, 0, 0): 100000.0,
#    datetime.datetime(2023, 8, 8, 0, 0): 99659.19213139801,
#    datetime.datetime(2023, 8, 9, 0, 0): 98457.05673178364,
#    datetime.datetime(2023, 8, 10, 0, 0): 98380.28056677215,
#    datetime.datetime(2023, 8, 11, 0, 0): 98791.06306158828,
#    datetime.datetime(2023, 8, 14, 0, 0): 99653.88091600276,
#    datetime.datetime(2023, 8, 15, 0, 0): 100805.7416603005,
#    datetime.datetime(2023, 8, 16, 0, 0): 100083.12534104551,
#    datetime.datetime(2023, 8, 17, 0, 0): 99703.9373021936,
#    datetime.datetime(2023, 8, 18, 0, 0): 98804.21377641965,
#    datetime.datetime(2023, 8, 21, 0, 0): 98229.1110080396,
#    datetime.datetime(2023, 8, 22, 0, 0): 99526.70277201789,
#    datetime.datetime(2023, 8, 23, 0, 0): 97510.25983120521,
#    datetime.datetime(2023, 8, 24, 0, 0): 97341.6651205937,
#    datetime.datetime(2023, 8, 25, 0, 0): 96429.99136018043,
#    datetime.datetime(2023, 8, 28, 0, 0): 97165.15815417077,
#    datetime.datetime(2023, 8, 29, 0, 0): 96190.98666739423,
#    datetime.datetime(2023, 8, 30, 0, 0): 96117.63005202082,
#    datetime.datetime(2023, 8, 31, 0, 0): 96898.94257703082,
#    datetime.datetime(2023, 9, 1, 0, 0): 95668.41400196443,
#    datetime.datetime(2023, 9, 4, 0, 0): 95703.66446578632,
#    datetime.datetime(2023, 9, 5, 0, 0): 95839.97353486849,
#    datetime.datetime(2023, 9, 6, 0, 0): 95872.51382371131,
#    datetime.datetime(2023, 9, 7, 0, 0): 96417.22261631927,
#    datetime.datetime(2023, 9, 8, 0, 0): 95353.5062206701,
#    datetime.datetime(2023, 9, 11, 0, 0): 96454.47388046129,
#    datetime.datetime(2023, 9, 12, 0, 0): 96394.37711448217,
#    datetime.datetime(2023, 9, 13, 0, 0): 95036.19747899161,
#    datetime.datetime(2023, 9, 14, 0, 0): 92771.50978573249,
#    datetime.datetime(2023, 9, 15, 0, 0): 92245.99048710395,
#    datetime.datetime(2023, 9, 18, 0, 0): 91952.58221470407,
#    datetime.datetime(2023, 9, 19, 0, 0): 92145.78676925317,
#    datetime.datetime(2023, 9, 20, 0, 0): 93298.12042999019,
#    datetime.datetime(2023, 9, 21, 0, 0): 93503.72994652406,
#    datetime.datetime(2023, 9, 22, 0, 0): 94703.48257484812,
#    datetime.datetime(2023, 9, 25, 0, 0): 94586.49032340209,
#    datetime.datetime(2023, 9, 26, 0, 0): 96353.7972461712,
#    datetime.datetime(2023, 9, 27, 0, 0): 95530.3769689694,
#    datetime.datetime(2023, 9, 28, 0, 0): 94975.15488013388},
#   ({datetime.datetime(2023, 8, 8, 0, 0): (37.74,
#      1360.544217687075,
#      -51346.938775510214,
#      256.734693877551)},
#    {datetime.datetime(2023, 8, 8, 0, 0): (37.41,
#      -1336.8983957219252,
#      50013.36898395722,
#      250.06684491978612)}))}

# %%
for pair_strat, pairs in filtered_pairs.items():
    print("Doing Backtesting for ", pair_strat)
    pairs["SharpeRatio"] = np.nan
    pairs["Annualised Return(%)"] = np.nan
    pairs["Max Drawdown(%)"] = np.nan
    pairs["Annualised Volatility(%)"] = np.nan
    raw_results = {}
    indexes = pairs.index
    for (index, (stock1, stock2)) in enumerate(pairs["pair"]):
        print("Backtesting for ", (stock1, stock2))
        stock1_df = read_stock_price(stock1)
        stock2_df = read_stock_price(stock2)
        if stock1_df.isnull().values.any() or stock2_df.isnull().values.any():
            print(f'{stock1} or {stock2} has null values')
            continue
        try:
            res = run_backtest(stock1, stock2, stock1_df, stock2_df, PARAMS)
        except IndexError:
            print('Index Error')
        portfolio_value = res.analyzers.cashvalueanalyzer.get_analysis()
        volatility = calculate_volatility(portfolio_value.values())
        orders = res.analyzers.orderanalyzer.get_analysis()
        
        # Raw results store the portfolio value at each date, and also the specific orders which were made during backtesting
        raw_results[(stock1, stock2)] = (portfolio_value, orders)        
        
        pairs.at[indexes[index], "SharpeRatio"] = res.analyzers.sharpe.get_analysis()["sharperatio"]
        pairs.at[indexes[index], "Annualised Return(%)"] = res.analyzers.returns.get_analysis()["rnorm100"]
        pairs.at[indexes[index], "Max Drawdown(%)"] = res.analyzers.drawdown.get_analysis()["max"]["drawdown"]
        pairs.at[indexes[index], "Annualised Volatility(%)"] = volatility
    backtest_results_raw[pair_strat] = raw_results
# Out:
# Doing Backtesting for  KMeans
# Backtesting for  ('Communication Services-Communication Services - 002027.SZ.csv', 'Healthcare-Healthcare - 300142.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 002027.SZ.csv', 'Industry-Industry - 000786.SZ.csv')
# Backtesting for  ('Healthcare-Healthcare - 300142.SZ.csv', 'Healthcare-Healthcare - 600763.SH.csv')
# Backtesting for  ('Healthcare-Healthcare - 300142.SZ.csv', 'Industry-Industry - 000786.SZ.csv')
# Backtesting for  ('Healthcare-Healthcare - 300142.SZ.csv', 'Industry-Industry - 601919.SH.csv')
# Backtesting for  ('Healthcare-Healthcare - 300142.SZ.csv', 'Materials-Materials - 600346.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 000983.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 600188.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 601225.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 601699.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 601808.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Energy-Energy - 601898.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 000157.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Energy-Energy - 000723.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Energy-Energy - 600188.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Energy-Energy - 601225.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Energy-Energy - 601699.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Energy-Energy - 601808.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 000408.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Energy-Energy - 000983.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Energy-Energy - 601225.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Energy-Energy - 601699.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Energy-Energy - 601808.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Energy-Energy - 601898.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Energy-Energy - 600188.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Energy-Energy - 601898.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 000157.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Energy-Energy - 601225.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Energy-Energy - 601808.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Energy-Energy - 601699.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Energy-Energy - 601808.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 000157.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Energy-Energy - 601898.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 000157.SZ.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Finance-Finance - 000617.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 000157.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 000425.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 000338.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 000768.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 000408.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 000425.SZ.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 000768.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 000800.SZ.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 600039.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 600760.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 600031.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600039.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Industry-Industry - 600150.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 600089.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 600150.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Industry-Industry - 600893.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 600760.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 600875.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 600893.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Industry-Industry - 601618.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Information Technology-Information Technology - 601360.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 601117.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Industry-Industry - 601872.SH.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 601618.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 002064.SZ.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 002648.SZ.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Real Estate-Real Estate - 600606.SH.csv')
# Backtesting for  ('Industry-Industry - 601872.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 002493.SZ.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 600547.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Industry-Industry - 601989.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Information Technology-Information Technology - 601360.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Information Technology-Information Technology - 601360.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# ...
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Information Technology-Information Technology - 603019.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Materials-Materials - 000301.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 000063.SZ.csv', 'Materials-Materials - 601600.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 000333.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 000625.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 002594.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 600104.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 600660.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 601238.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 601888.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 000568.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 000596.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 000858.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 000876.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 000895.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 002304.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 002714.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 600132.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 600519.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 600600.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 600809.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 600887.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 603288.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Consumer Staples-Consumer Staples - 603369.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 000983.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 600188.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 601225.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 601808.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 601857.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Energy-Energy - 601898.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 000001.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 000617.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 000776.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 002142.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 002736.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600000.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600015.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600016.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600030.SH.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600837.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 600999.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601009.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601166.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601288.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601318.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601377.SH.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601398.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601601.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601628.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601688.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601788.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601818.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601901.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601939.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601988.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Finance-Finance - 601998.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 000661.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 000963.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 002001.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 002007.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 300015.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 300122.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Healthcare-Healthcare - 300142.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 000157.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 000338.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 000800.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002120.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002129.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002179.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002202.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002271.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002352.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 002459.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 300207.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600009.SH.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600018.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600029.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600031.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600089.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600115.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600233.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600406.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 600875.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601117.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601186.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601669.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601800.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601877.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Industry-Industry - 601989.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 000100.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 000725.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 000733.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002049.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002230.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002236.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002241.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002371.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002415.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 002475.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 300033.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 300408.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 600183.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 600460.SH.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Information Technology-Information Technology - 600588.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 000408.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 000708.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 000792.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 000877.SZ.csv')
# Index Error
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 002601.SZ.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600010.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600019.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600111.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600176.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600219.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600309.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600362.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600426.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 600585.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 601899.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Materials-Materials - 603993.SH.csv')
# Backtesting for  ('Communication Services-Communication Services - 600050.SH.csv', 'Utilities-Utilities - 600803.SH.csv')
# Index Error

# %%
import pickle
pickle.dump(filtered_pairs, open('results_df.pickle', 'wb'))
pickle.dump(backtest_results_raw, open('results_raw.pickle', 'wb'))

# %%
import pickle

# %%
test = pickle.load(open('results_df.pickle', 'rb'))

# %%
test
# Out:
# {'KMeans':                                                    pair        pvalue  \
#  0     (Communication Services-Communication Services...  1.024104e-03
#  2     (Communication Services-Communication Services...  1.370479e-05
#  5     (Healthcare-Healthcare - 300142.SZ.csv, Health...  2.835066e-02
#  6     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  1.871553e-02
#  7     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  2.565211e-02
#  ...                                                 ...           ...
#  3310  (Industry-Industry - 002709.SZ.csv, Industry-I...  0.000000e+00
#  3314  (Industry-Industry - 300014.SZ.csv, Industry-I...  0.000000e+00
#  3315  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
#  3316  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
#  3317  (Industry-Industry - 600884.SH.csv, Materials-...  1.813381e-29
#
#        hurst_exp   half_life  avg_cross_count  SharpeRatio  \
#  0      0.045492    1.693115       111.770021    -0.317954
#  2      0.028210    2.532232       111.252567    -0.022183
#  5      0.066402    4.820998        96.936345     0.914259
#  6      0.028967    8.024377       103.663244     0.223169
#  7      0.097647    8.811799       106.595483    -1.441624
#  ...         ...         ...              ...          ...
#  3310   0.000400  157.778025       128.845996    -0.928773
#  3314   0.005210   11.634979       126.776181     0.682757
#  3315   0.007635   51.272003       124.188912    -0.291994
#  3316   0.006595   59.069991       119.531828     2.597981
#  3317   0.003271   15.703670       129.363450    -1.286802
#
#        Annualised Return(%)  Max Drawdown(%)  Annualised Volatility(%)
#  0                -0.801610        28.303495                 22.794377
#  2                 0.343329        20.664132                 16.446214
#  5                11.509316        16.114526                 16.608799
#  6                 1.329542         8.803951                  9.481991
#  7                -2.379265        12.166765                 15.921455
#  ...                    ...              ...                       ...
#  3310             -4.339996        31.344279                 17.586267
#  3314             10.917467        22.495830                 15.769745
#  3315             -0.381570        26.338041                 17.427966
#  3316              7.084105        24.367752                 20.618151
#  3317             -3.686190        21.736503                 16.518060
#
#  [1815 rows x 9 columns],
#  'Agglo':                                                  pair    pvalue  hurst_exp  \
#  0   (Communication Services-Communication Services...  0.006741   0.053243
#  1   (Communication Services-Communication Services...  0.032566   0.054124
#  2   (Communication Services-Communication Services...  0.003626   0.057317
#  3   (Communication Services-Communication Services...  0.002735   0.053958
#  4   (Communication Services-Communication Services...  0.002167   0.055102
#  ..                                                ...       ...        ...
#  67  (Communication Services-Communication Services...  0.002896   0.055350
#  68  (Communication Services-Communication Services...  0.002647   0.053475
#  70  (Communication Services-Communication Services...  0.002485   0.053928
#  71  (Communication Services-Communication Services...  0.001743   0.052262
#  72  (Communication Services-Communication Services...  0.002756   0.055481
#
#      half_life  avg_cross_count  SharpeRatio  Annualised Return(%)  \
#  0   57.754258       110.045175     0.927248              9.285830
#  1   57.083765       109.527721    -2.941426            -20.249193
#  2   57.302884       111.080082    -2.760451            -11.443378
#  3   57.535480       112.114990    -1.021898             -1.273889
#  4   57.562617       107.285421    -1.021898             -1.273889
#  ..        ...              ...          ...                   ...
#  67  57.595307       110.390144     0.309830              3.937774
#  68  57.863895       110.390144    -0.773412             -0.173924
#  70  57.784840       113.494867     0.176233              2.346937
#  71  57.998827       109.355236    -1.364539             -3.847216
#  72  57.688107       112.459959    -1.364539             -3.847216
#
#      Max Drawdown(%)  Annualised Volatility(%)
#  0         21.808760                 18.358713
#  1         39.717114                 22.839739
#  2         25.972767                 22.656170
#  3         15.964426                 15.799070
#  4         15.964426                 15.799070
#  ..              ...                       ...
#  67        11.542264                 13.351348
#  68        15.589332                 13.402622
#  70        16.456319                 15.484122
#  71        14.060280                 16.985303
#  72        14.060280                 16.985303
#
#  [69 rows x 9 columns],
#  'DBSCAN':                                                   pair        pvalue  \
#  0    (Communication Services-Communication Services...  1.283926e-17
#  5    (Communication Services-Communication Services...  3.241014e-18
#  9    (Communication Services-Communication Services...  0.000000e+00
#  23   (Communication Services-Communication Services...  2.651843e-11
#  28   (Communication Services-Communication Services...  1.627593e-18
#  ..                                                 ...           ...
#  337  (Communication Services-Communication Services...  1.832293e-23
#  339  (Communication Services-Communication Services...  1.423910e-19
#  341  (Communication Services-Communication Services...  0.000000e+00
#  342  (Communication Services-Communication Services...  1.677731e-17
#  350  (Communication Services-Communication Services...  2.620260e-17
#
#       hurst_exp   half_life  avg_cross_count  SharpeRatio  \
#  0     0.001681   58.658545       119.704312    -1.155739
#  5     0.006920  215.050697       132.985626     0.833828
#  9    -0.007808  245.102818       122.119097    -1.188046
#  23   -0.000664  249.534483       124.878850    -1.418252
#  28   -0.002497  231.619843       127.638604    -1.418252
#  ..         ...         ...              ...          ...
#  337   0.002654   80.990246       120.911704    -1.246701
#  339   0.003709   77.639329       119.014374   -36.998088
#  341   0.000858   82.353605       122.981520     1.418206
#  342   0.002548   84.999596       122.809035     0.939350
#  350   0.000470   80.265233       122.464066     0.939350
#
#       Annualised Return(%)  Max Drawdown(%)  Annualised Volatility(%)
#  0               -6.892551        24.089725                 14.435432
#  5                6.082813        11.407500                 11.869571
#  9               -5.675305        28.693890                 19.561999
#  23              -2.513799        22.290054                 15.141982
#  28              -2.513799        22.290054                 15.141982
#  ..                    ...              ...                       ...
#  337             -4.297766        21.149713                 17.487202
#  339             -2.911067        18.743077                 14.921783
#  341              8.177697        20.260071                 17.114579
#  342             10.770715        19.841529                 17.444936
#  350             10.770715        19.841529                 17.444936
#
#  [165 rows x 9 columns]}

# %%
test['KMeans']
# Out:
#                                                    pair        pvalue  \
# 0     (Communication Services-Communication Services...  1.024104e-03
# 2     (Communication Services-Communication Services...  1.370479e-05
# 5     (Healthcare-Healthcare - 300142.SZ.csv, Health...  2.835066e-02
# 6     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  1.871553e-02
# 7     (Healthcare-Healthcare - 300142.SZ.csv, Indust...  2.565211e-02
# ...                                                 ...           ...
# 3310  (Industry-Industry - 002709.SZ.csv, Industry-I...  0.000000e+00
# 3314  (Industry-Industry - 300014.SZ.csv, Industry-I...  0.000000e+00
# 3315  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
# 3316  (Industry-Industry - 300014.SZ.csv, Materials-...  0.000000e+00
# 3317  (Industry-Industry - 600884.SH.csv, Materials-...  1.813381e-29
#
#       hurst_exp   half_life  avg_cross_count  SharpeRatio  \
# 0      0.045492    1.693115       111.770021    -0.317954
# 2      0.028210    2.532232       111.252567    -0.022183
# 5      0.066402    4.820998        96.936345     0.914259
# 6      0.028967    8.024377       103.663244     0.223169
# 7      0.097647    8.811799       106.595483    -1.441624
# ...         ...         ...              ...          ...
# 3310   0.000400  157.778025       128.845996    -0.928773
# 3314   0.005210   11.634979       126.776181     0.682757
# 3315   0.007635   51.272003       124.188912    -0.291994
# 3316   0.006595   59.069991       119.531828     2.597981
# 3317   0.003271   15.703670       129.363450    -1.286802
#
#       Annualised Return(%)  Max Drawdown(%)  Annualised Volatility(%)
# 0                -0.801610        28.303495                 22.794377
# 2                 0.343329        20.664132                 16.446214
# 5                11.509316        16.114526                 16.608799
# 6                 1.329542         8.803951                  9.481991
# 7                -2.379265        12.166765                 15.921455
# ...                    ...              ...                       ...
# 3310             -4.339996        31.344279                 17.586267
# 3314             10.917467        22.495830                 15.769745
# 3315             -0.381570        26.338041                 17.427966
# 3316              7.084105        24.367752                 20.618151
# 3317             -3.686190        21.736503                 16.518060
#
# [1815 rows x 9 columns]

# %%
kmeans = test['KMeans']

# %%
kmeans[(kmeans['SharpeRatio'] > 1.5) & (kmeans['SharpeRatio'] < 10)].to_csv("kmeans_chinamarket.csv")

# %%
dbscan = test['DBSCAN']

# %%
len(dbscan)
# Out:
# 165

# %%
dbscan[dbscan['SharpeRatio'] > 1.5].to_csv("dbscan_chinamarket.csv")

# %%
agglo = test['Agglo']

# %%
agglo[agglo['SharpeRatio'] > 1.5].to_csv("agglo_chinamarket.csv")

# %%
# def read_stock_price(file_path: str):
#     df = pd.read_csv(file_path, header=[0, 1]).drop(0)
#     # Skipping files with null values for now
#     if df.isnull().values.any():
#         print(f'{file_path} has null values')
#         return None
#     dates = pd.to_datetime(df.iloc[:, 0], utc=True).dt.date
#     dates = pd.to_datetime(dates)
#     dates.name = "Date"
#     df.index = dates
#     return df

# %%
# prices = {}
# files = get_files(path="Data", extension="csv")
# for file_name, file_path in files.items():
#     df = read_stock_price(file_path)
#     if df is not None:
#         prices[file_name] = df

# %%
# results = {}
# for file, stock_price in prices.items():
#     print(f"Getting results for {file}")
#     testing_prices = stock_price.loc[stock_price.index < TESTING_CUTOFF]
#     testing_prices = testing_prices.iloc[:, testing_prices.columns.get_level_values(1) == "Adj Close"]
    
#     stocks = testing_prices.columns.get_level_values(0)
#     testing_prices.columns = stocks
#     pairs = pd.Series([(stocks[i], stocks[j]) for i in range(len(stocks)) for j in range(i+1, len(stocks))])
#     results[file] = find_suitable_pairs(testing_prices, pairs)

# %%
# backtest_res = {}
# for file, (all_pairs_df, filtered_pairs_df) in results.items():
#     for pair in filtered_pairs_df['pair']:
#         print(f"Doing backtesting for: {pair}")
#         stock_prices = prices[file].loc[stock_price.index > TESTING_CUTOFF]
#         res = run_backtest(pair[0], pair[1], stock_prices[pair[0]], stock_prices[pair[1]], PARAMS)
#         backtest_res[file] = res
#         res.analyzers.sharpe.print()
#         res.analyzers.returns.print()
#         print('Ending test\n')
#         print('\n')
