# %%
# %%writefile requirements.txt
# backtrader==1.9.76.123
# matplotlib==3.6.3
# numpy==1.24.1
# pandas==1.5.3
# pytz==2022.7.1
# scikit-learn==1.2.0
# scipy==1.10.0
# seaborn==0.12.2
# statsmodels==0.13.5
# Out:
# Writing requirements.txt

# %%
import pandas as pd
import yfinance as yf
import numpy as np
from functools import reduce
import os
import glob

# %%
data = pd.read_excel("China.xlsx")

# %%
data.drop(columns=["Unnamed: 0"], inplace=True)

# %%
industries = list(data.industry.unique())

# %%
data
# Out:
#           ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0       000001.SZ    20230928  11.19  11.24  11.18  11.20      11.17    0.03
# 1       000001.SZ    20230927  11.15  11.22  11.15  11.17      11.16    0.01
# 2       000001.SZ    20230926  11.22  11.26  11.14  11.16      11.22   -0.06
# 3       000001.SZ    20230925  11.24  11.32  11.19  11.22      11.24   -0.02
# 4       000001.SZ    20230922  11.03  11.25  11.03  11.24      11.05    0.19
# ...           ...         ...    ...    ...    ...    ...        ...     ...
# 198020  688981.SH    20210108  58.71  61.85  58.03  61.59      59.23    2.36
# 198021  688981.SH    20210107  60.96  61.68  57.81  59.23      60.55   -1.32
# 198022  688981.SH    20210106  58.66  61.88  58.44  60.55      58.77    1.78
# 198023  688981.SH    20210105  57.00  58.79  56.80  58.77      58.26    0.51
# 198024  688981.SH    20210104  58.37  59.06  56.75  58.26      57.75    0.51
#
#         pct_chg        vol       amount                industry
# 0        0.2686  520696.78   583649.730                 Finance
# 1        0.0896  490310.61   547905.821                 Finance
# 2       -0.5348  444980.35   497885.811                 Finance
# 3       -0.1779  761211.25   856022.502                 Finance
# 4        1.7195  911484.30  1017137.922                 Finance
# ...         ...        ...          ...                     ...
# 198020   3.9845  599996.06  3646079.780  Information Technology
# 198021  -2.1800  435909.14  2593184.284  Information Technology
# 198022   3.0288  518865.20  3133441.233  Information Technology
# 198023   0.8754  388172.32  2255983.763  Information Technology
# 198024   0.8831  396526.38  2305861.381  Information Technology
#
# [198025 rows x 12 columns]

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
for industry in industries:
    new_data = data[data.industry == industry]
    list_of_companies = list(new_data.ts_code.unique())
    print("######################################################")
    print(industry)
    for company in list_of_companies:
        data_of_company = new_data[new_data.ts_code == company]
        newpath = 'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data/' + industry
        if not os.path.exists(newpath):
            os.makedirs(newpath)
        data_of_company = data_of_company[::-1]
        data_of_company['Returns'] = np.log(data_of_company['close']/data_of_company['close'].shift(1))
        data_of_company['Date'] = data_of_company['trade_date']
        data_of_company['adj close'] = data_of_company['close']
#         print(data_of_company)
        data_of_company.to_csv(f"{newpath}/{industry} - {company}.csv")
# Out:
# ######################################################
# Finance
# ######################################################
# Real Estate
# ######################################################
# Communication Services
# ######################################################
# Information Technology
# ######################################################
# Industry
# ######################################################
# Materials
# ######################################################
# Consumer Discretionary
# ######################################################
# Healthcare
# ######################################################
# Consumer Staples
# ######################################################
# Energy
# ######################################################
# Utilities

# %%
dirs = glob.glob("C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data/*", recursive = True)
dirs
# Out:
# ['C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Communication Services',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Consumer Discretionary',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Consumer Staples',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Energy',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Finance',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Healthcare',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Industry',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Information Technology',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Materials',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Real Estate',
#  'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data\\Utilities']

# %%
data_of_company
# Out:
#           ts_code  trade_date  open  high   low  close  pre_close  change  \
# 172737  601985.SH    20210104  4.92  4.95  4.85   4.95       4.92    0.03
# 172736  601985.SH    20210105  4.87  4.89  4.75   4.86       4.95   -0.09
# 172735  601985.SH    20210106  4.85  5.04  4.81   5.01       4.86    0.15
# 172734  601985.SH    20210107  4.97  5.08  4.92   5.02       5.01    0.01
# 172733  601985.SH    20210108  5.04  5.08  4.96   5.02       5.02    0.00
# ...           ...         ...   ...   ...   ...    ...        ...     ...
# 172075  601985.SH    20230922  7.36  7.39  7.27   7.28       7.36   -0.08
# 172074  601985.SH    20230925  7.29  7.39  7.28   7.32       7.28    0.04
# 172073  601985.SH    20230926  7.33  7.38  7.30   7.32       7.32    0.00
# 172072  601985.SH    20230927  7.33  7.39  7.28   7.31       7.32   -0.01
# 172071  601985.SH    20230928  7.33  7.35  7.26   7.30       7.31   -0.01
#
#         pct_chg         vol      amount   industry   Returns      Date  \
# 172737   0.6098   595868.47  292189.486  Utilities       NaN  20210104
# 172736  -1.8182   894550.51  432078.255  Utilities -0.018349  20210105
# 172735   3.0864  1014713.24  502200.170  Utilities  0.030397  20210106
# 172734   0.1996   834113.22  417081.859  Utilities  0.001994  20210107
# 172733   0.0000   728448.80  364681.682  Utilities  0.000000  20210108
# ...         ...         ...         ...        ...       ...       ...
# 172075  -1.0870   480978.49  350954.302  Utilities -0.010929  20230922
# 172074   0.5495   468621.26  344008.300  Utilities  0.005479  20230925
# 172073   0.0000   259281.87  190269.953  Utilities  0.000000  20230926
# 172072  -0.1366   458524.81  335923.535  Utilities -0.001367  20230927
# 172071  -0.1368   297615.64  216965.231  Utilities -0.001369  20230928
#
#         adj close
# 172737       4.95
# 172736       4.86
# 172735       5.01
# 172734       5.02
# 172733       5.02
# ...           ...
# 172075       7.28
# 172074       7.32
# 172073       7.32
# 172072       7.31
# 172071       7.30
#
# [667 rows x 15 columns]

# %%
'''Set up constants'''
start_train = '2021-01-01'
end_train = '2022-12-31'

start_test = '2023-01-01'
end_test = '2023-09-29'

# %%
from datetime import datetime

# %%
def get_files(path: str, extension: str):
    files = glob.glob(path + f"/*{extension}")
    return {os.path.basename(path) + '-' + os.path.basename(file):file for file in files}

def parse_date(date: str) -> datetime:
  return datetime.strptime(date, '%Y-%m-%d')

def get_dataframe(start_train, end_train, start_test, end_test, paths):
    df_list = []
    for path in paths:
        paths_dict = get_files(path, extension = '.csv')
        for symbol, file_path in paths_dict.items():
            df = pd.read_csv(file_path, parse_dates = ['Date'])
#             print(file_path)
#             print(df)
            if df.shape[0] == 0:
                continue
            dates = pd.to_datetime(df['Date'], format="%Y%m%d", utc=True)
            dates = dates.dt.strftime("%Y-%m-%d")
            df['Date'] = dates
            df['Date'] = pd.to_datetime(df['Date'])
            print(df.dtypes)
#             df['Date'] = df['Date'].apply(lambda x: x.replace(tzinfo = None))
            if df['Date'].iloc[0] > parse_date(start_train) or df['Date'].iloc[-1] < parse_date(end_test):
                print("Error")
                print(symbol)
                continue
            else:
                df = df.set_index('Date', drop = True)
    #                 df[symbol] = np.log(df["Adj Close"]/df["Adj Close"].shift(1))
                df[symbol] = df['Returns']
                log_returns = df[symbol][start_train:end_train]
                log_returns.dropna(inplace = True)
                print(log_returns)
                df_list.append(log_returns)

    return df_list

# %%
df_list = get_dataframe(start_train, end_train, start_test, end_test, dirs)
# Out:
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 000063.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 000938.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 002027.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 002555.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 300413.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 300628.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 600050.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 600941.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 601698.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Communication Services-Communication Services - 601728.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 000333.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 000625.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 000651.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 002050.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 002594.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 002920.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 300979.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 600104.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 600660.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 600690.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 600741.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 600754.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 601238.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 601633.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 601689.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 601799.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 601888.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 603195.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 603486.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 603833.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Discretionary-Consumer Discretionary - 605117.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 000568.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 000596.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 000858.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 000876.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 000895.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 002304.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 002311.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 002714.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 300498.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 300957.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 300999.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 600132.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 600519.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 600600.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 600809.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 600887.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 603288.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 603369.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 605499.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Consumer Staples-Consumer Staples - 688363.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 000723.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 000983.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 600028.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 600188.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601088.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601225.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601699.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601808.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601857.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Energy-Energy - 601898.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 000001.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 000166.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 000617.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 000776.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 002142.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 002736.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 300059.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600000.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600015.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600016.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600030.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600036.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600061.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600837.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600918.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600919.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600926.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600958.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 600999.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601009.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601066.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601166.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601169.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601211.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601229.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601236.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601288.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601318.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Finance-Finance - 601319.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# ...
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600346.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600362.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600426.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600547.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600585.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 600989.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 601216.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 601600.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 601899.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 603260.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 603799.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 603993.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Materials-Materials - 688065.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 000002.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 000069.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 001979.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 600048.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 600383.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 600606.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Real Estate-Real Estate - 601155.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 001289.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 003816.SZ.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600011.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600025.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600674.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600795.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600803.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600886.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600900.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 600905.SH.csv
# Unnamed: 0             int64
# ts_code               object
# trade_date             int64
# open                 float64
# high                 float64
# low                  float64
# close                float64
# pre_close            float64
# change               float64
# pct_chg              float64
# vol                  float64
# amount               float64
# industry              object
# Returns              float64
# Date          datetime64[ns]
# adj close            float64
# dtype: object
# Error
# Utilities-Utilities - 601985.SH.csv

# %%
df_list
# Out:
# []

# %%
def combine(list_of_df):
  df = pd.concat(list_of_df, axis = 1)
  df.dropna(axis = 1, thresh = int(len(df) * 0.60), inplace = True) #require that each asset have at least 75% of data
  df.fillna(method = 'ffill', axis = 0, inplace = True) #fill NAs by forward filling
  return df

df = combine(df_list)
df_T = df.T

print('Concatenated dataframe along columns: \n', df.iloc[:5, :5])
print('\nTransposed dataframe: \n', df_T.iloc[:5,:5])
# Out:
# Concatenated dataframe along columns:
#              Communication Services-Communication Services - 000063.SZ.csv  \
# Date
# 2021-01-05                                           0.005230
# 2021-01-06                                          -0.025831
# 2021-01-07                                          -0.028961
# 2021-01-08                                           0.036958
# 2021-01-11                                           0.029931
#
#             Communication Services-Communication Services - 000938.SZ.csv  \
# Date
# 2021-01-05                                           0.023925
# 2021-01-06                                          -0.019576
# 2021-01-07                                          -0.025392
# 2021-01-08                                           0.095220
# 2021-01-11                                           0.051271
#
#             Communication Services-Communication Services - 002027.SZ.csv  \
# Date
# 2021-01-05                                          -0.017077
# 2021-01-06                                           0.052306
# 2021-01-07                                           0.022815
# 2021-01-08                                           0.025975
# 2021-01-11                                           0.037740
#
#             Communication Services-Communication Services - 002555.SZ.csv  \
# Date
# 2021-01-05                                           0.047686
# 2021-01-06                                          -0.009900
# 2021-01-07                                          -0.051976
# 2021-01-08                                           0.072564
# 2021-01-11                                           0.037390
#
#             Communication Services-Communication Services - 300413.SZ.csv
# Date
# 2021-01-05                                          -0.051813
# 2021-01-06                                           0.004182
# 2021-01-07                                          -0.013036
# 2021-01-08                                           0.026047
# 2021-01-11                                           0.102516
#
# Transposed dataframe:
#  Date                                                2021-01-05  2021-01-06  \
# Communication Services-Communication Services -...    0.005230   -0.025831
# Communication Services-Communication Services -...    0.023925   -0.019576
# Communication Services-Communication Services -...   -0.017077    0.052306
# Communication Services-Communication Services -...    0.047686   -0.009900
# Communication Services-Communication Services -...   -0.051813    0.004182
#
# Date                                                2021-01-07  2021-01-08  \
# Communication Services-Communication Services -...   -0.028961    0.036958
# Communication Services-Communication Services -...   -0.025392    0.095220
# Communication Services-Communication Services -...    0.022815    0.025975
# Communication Services-Communication Services -...   -0.051976    0.072564
# Communication Services-Communication Services -...   -0.013036    0.026047
#
# Date                                                2021-01-11
# Communication Services-Communication Services -...    0.029931
# Communication Services-Communication Services -...    0.051271
# Communication Services-Communication Services -...    0.037740
# Communication Services-Communication Services -...    0.037390
# Communication Services-Communication Services -...    0.102516

# %%
df_T.shape
# Out:
# (297, 305)

# %%
df_T.dropna(axis = 1, inplace = True)

# %%
df_T.shape
# Out:
# (297, 305)

# %% [markdown]
# ## Scaling

# %%
import seaborn as sns
import glob
import os
import typing
import warnings
import matplotlib.pyplot as plt
#import tensorflow as tf

from itertools import combinations, chain
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from datetime import datetime
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy import stats
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, OPTICS, cluster_optics_dbscan
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestNeighbors
import statsmodels.api as sm
import statsmodels.tsa.stattools as ts
import pytz
# warnings.filterwarnings("ignore")

# %%
def standardize(df: pd.DataFrame):
    scaler = StandardScaler()
    normalized = scaler.fit_transform(df)
    #symbols = df.index

    return normalized

normalized = standardize(df_T)
df_norm = pd.DataFrame(normalized, index = df_T.index, columns = df_T.columns)

# %% [markdown]
# ## PCA

# %%
def optimize_pca(df):

    explained_variance = []
    principal_components = []

    for i in range(1,51):
        pca = PCA(n_components = i)
        pca.fit_transform(df)
        explained_variance.append(sum(pca.explained_variance_ratio_))
        principal_components.append(i)

    plt.figure(figsize = (7,4))
    plt.plot(principal_components, explained_variance, color = 'black', marker = 'o')
    plt.axvline(x=9, )
    plt.title('Explained variance against number of principal components')
    plt.xlabel('No. of Principal Components')
    plt.ylabel('Percentage of variance explained')


def final_pca(df, n):

    pca = PCA(n_components = n)
    components = pca.fit_transform(df)
    explained_variance = sum(pca.explained_variance_ratio_)
    

    pca_df = pd.DataFrame(components, columns = [f"PC{k}" for k in range(1, n+1)], index = df.index)
    print(f"Total percentage of variance explained with {n} principal components: {round(explained_variance, 3)}")
    return pca_df

# %%
optimize_pca(df_norm)
plt.axvline(x=8, color = 'black')

# %% [markdown]
# ###### From the plot, the elbow point of the curve gives 9  as the optimal number of Principal Components

# %%
pca_df = final_pca(df_norm, 9)
# Out:
# Total percentage of variance explained with 9 principal components: 0.363

# %%
pca_df
# Out:
#                                                          PC1       PC2  \
# Communication Services-Communication Services -... -1.393611 -3.317084
# Communication Services-Communication Services -... -0.152787 -1.972161
# Communication Services-Communication Services -... -4.365953 -6.076754
# Communication Services-Communication Services -... -3.200594 -5.707823
# Communication Services-Communication Services -... -2.932753 -7.038817
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -2.911520  4.339023
# Utilities-Utilities - 600886.SH.csv                -2.597226  4.397263
# Utilities-Utilities - 600900.SH.csv                -4.333178  2.550497
# Utilities-Utilities - 600905.SH.csv                -0.790437  2.868300
# Utilities-Utilities - 601985.SH.csv                -2.728036  4.875551
#
#                                                          PC3       PC4  \
# Communication Services-Communication Services -...  1.609912 -0.339521
# Communication Services-Communication Services -...  4.134690 -0.299907
# Communication Services-Communication Services -... -4.213454 -2.709115
# Communication Services-Communication Services -...  1.802459  0.819092
# Communication Services-Communication Services -...  1.167620 -1.555260
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -0.633838  0.188865
# Utilities-Utilities - 600886.SH.csv                 1.398309  4.433166
# Utilities-Utilities - 600900.SH.csv                 1.069864  2.581114
# Utilities-Utilities - 600905.SH.csv                 2.010651  3.561457
# Utilities-Utilities - 601985.SH.csv                 2.008288  1.807844
#
#                                                          PC5       PC6  \
# Communication Services-Communication Services -...  0.195285  0.633685
# Communication Services-Communication Services -...  0.983255  0.968044
# Communication Services-Communication Services -... -1.117354 -1.347128
# Communication Services-Communication Services -... -0.402213 -0.852906
# Communication Services-Communication Services -...  0.777377 -1.838597
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 3.321757 -2.764405
# Utilities-Utilities - 600886.SH.csv                 1.171467 -1.546731
# Utilities-Utilities - 600900.SH.csv                 0.417694 -1.060023
# Utilities-Utilities - 600905.SH.csv                 0.857934 -0.562986
# Utilities-Utilities - 601985.SH.csv                 2.376284 -0.753135
#
#                                                          PC7       PC8  \
# Communication Services-Communication Services -... -1.087427  1.294273
# Communication Services-Communication Services -... -2.643640 -0.284317
# Communication Services-Communication Services -...  0.756668  3.670884
# Communication Services-Communication Services -... -0.961888  2.574774
# Communication Services-Communication Services -... -0.827694  4.877898
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 0.079118  2.671561
# Utilities-Utilities - 600886.SH.csv                -0.870411  3.189722
# Utilities-Utilities - 600900.SH.csv                -0.143738 -1.161847
# Utilities-Utilities - 600905.SH.csv                -0.995841  3.911186
# Utilities-Utilities - 601985.SH.csv                 0.202076  5.014005
#
#                                                          PC9
# Communication Services-Communication Services -... -0.090013
# Communication Services-Communication Services -... -0.038565
# Communication Services-Communication Services -...  1.783099
# Communication Services-Communication Services -... -0.251432
# Communication Services-Communication Services -...  0.529612
# ...                                                      ...
# Utilities-Utilities - 600803.SH.csv                -1.084160
# Utilities-Utilities - 600886.SH.csv                 0.695800
# Utilities-Utilities - 600900.SH.csv                 0.255208
# Utilities-Utilities - 600905.SH.csv                 0.826512
# Utilities-Utilities - 601985.SH.csv                 0.411284
#
# [297 rows x 9 columns]

# %%
pca_df.plot('PC1', 'PC2', marker = 'o', color = 'blue', kind = 'scatter', figsize = (16,8))
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %% [markdown]
# ## Clustering

# %%
pca_df
# Out:
#                                                          PC1       PC2  \
# Communication Services-Communication Services -... -1.393611 -3.317084
# Communication Services-Communication Services -... -0.152787 -1.972161
# Communication Services-Communication Services -... -4.365953 -6.076754
# Communication Services-Communication Services -... -3.200594 -5.707823
# Communication Services-Communication Services -... -2.932753 -7.038817
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -2.911520  4.339023
# Utilities-Utilities - 600886.SH.csv                -2.597226  4.397263
# Utilities-Utilities - 600900.SH.csv                -4.333178  2.550497
# Utilities-Utilities - 600905.SH.csv                -0.790437  2.868300
# Utilities-Utilities - 601985.SH.csv                -2.728036  4.875551
#
#                                                          PC3       PC4  \
# Communication Services-Communication Services -...  1.609912 -0.339521
# Communication Services-Communication Services -...  4.134690 -0.299907
# Communication Services-Communication Services -... -4.213454 -2.709115
# Communication Services-Communication Services -...  1.802459  0.819092
# Communication Services-Communication Services -...  1.167620 -1.555260
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -0.633838  0.188865
# Utilities-Utilities - 600886.SH.csv                 1.398309  4.433166
# Utilities-Utilities - 600900.SH.csv                 1.069864  2.581114
# Utilities-Utilities - 600905.SH.csv                 2.010651  3.561457
# Utilities-Utilities - 601985.SH.csv                 2.008288  1.807844
#
#                                                          PC5       PC6  \
# Communication Services-Communication Services -...  0.195285  0.633685
# Communication Services-Communication Services -...  0.983255  0.968044
# Communication Services-Communication Services -... -1.117354 -1.347128
# Communication Services-Communication Services -... -0.402213 -0.852906
# Communication Services-Communication Services -...  0.777377 -1.838597
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 3.321757 -2.764405
# Utilities-Utilities - 600886.SH.csv                 1.171467 -1.546731
# Utilities-Utilities - 600900.SH.csv                 0.417694 -1.060023
# Utilities-Utilities - 600905.SH.csv                 0.857934 -0.562986
# Utilities-Utilities - 601985.SH.csv                 2.376284 -0.753135
#
#                                                          PC7       PC8  \
# Communication Services-Communication Services -... -1.087427  1.294273
# Communication Services-Communication Services -... -2.643640 -0.284317
# Communication Services-Communication Services -...  0.756668  3.670884
# Communication Services-Communication Services -... -0.961888  2.574774
# Communication Services-Communication Services -... -0.827694  4.877898
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 0.079118  2.671561
# Utilities-Utilities - 600886.SH.csv                -0.870411  3.189722
# Utilities-Utilities - 600900.SH.csv                -0.143738 -1.161847
# Utilities-Utilities - 600905.SH.csv                -0.995841  3.911186
# Utilities-Utilities - 601985.SH.csv                 0.202076  5.014005
#
#                                                          PC9
# Communication Services-Communication Services -... -0.090013
# Communication Services-Communication Services -... -0.038565
# Communication Services-Communication Services -...  1.783099
# Communication Services-Communication Services -... -0.251432
# Communication Services-Communication Services -...  0.529612
# ...                                                      ...
# Utilities-Utilities - 600803.SH.csv                -1.084160
# Utilities-Utilities - 600886.SH.csv                 0.695800
# Utilities-Utilities - 600900.SH.csv                 0.255208
# Utilities-Utilities - 600905.SH.csv                 0.826512
# Utilities-Utilities - 601985.SH.csv                 0.411284
#
# [297 rows x 9 columns]

# %%
silhouette_scores = {}
cluster_results = {}

# %%
kmeans_kwargs = {
    "init": "k-means++",
    "n_init": 10,
    "max_iter": 5000,
}

def Kmeans_ParameterTesting_SSE(data):
# A list holds the SSE values for each k
    sse = []
    max_k = 20
    for k in range(2, max_k):
        kmeans = KMeans(n_clusters=k, **kmeans_kwargs, random_state= 2023)
        kmeans.fit(data)
        sse.append(kmeans.inertia_)

  
    plt.figure(figsize=(7,4))
    plt.plot(np.arange(2, max_k, 1), sse, color = 'black')
    plt.xticks(np.arange(2,max_k,1))
    plt.title('Within-cluster sum of squares against k')
    plt.xlabel("Number of Clusters")
    plt.ylabel("SSE")
    plt.axvline(x = 9, color = 'black', linestyle = '--')


def Kmeans_ParameterTesting_silhouette(data):

    silhouette_coefficients = []
    max_k = 20
    for k in range(2, max_k):
        kmeans = KMeans(n_clusters=k, **kmeans_kwargs, random_state= 2023)
        kmeans.fit(data)
        score = silhouette_score(data, kmeans.labels_)
        silhouette_coefficients.append(score)


    plt.figure(figsize=(16,8))
    plt.plot(range(2, max_k), silhouette_coefficients)
    plt.title("Silhouette score against k")
    plt.xlabel("Number of Clusters")
    plt.xticks(np.arange(2,max_k,1))
    plt.ylabel("Silhouette Coefficient")
    plt.show()

# %%
import sklearn

# %%
pip install threadpoolctl==3.2.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: threadpoolctl==3.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
sklearn.show_versions()
# Out:
# System:
#     python: 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:38:37) [MSC v.1916 64 bit (AMD64)]
# executable: C:\ProgramData\anaconda3\python.exe
#    machine: Windows-10-10.0.19045-SP0
#
# Python dependencies:
#       sklearn: 1.3.0
#           pip: 23.2.1
#    setuptools: 68.0.0
#         numpy: 1.24.3
#         scipy: 1.10.1
#        Cython: 3.0.2
#        pandas: 1.5.3
#    matplotlib: 3.7.1
#        joblib: 1.2.0
# threadpoolctl: 3.2.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        filepath: C:\ProgramData\anaconda3\Library\bin\mkl_rt.2.dll
#          prefix: mkl_rt
#        user_api: blas
#    internal_api: mkl
#         version: 2023.1-Product
#     num_threads: 6
# threading_layer: intel
#
#        filepath: C:\ProgramData\anaconda3\vcomp140.dll
#          prefix: vcomp
#        user_api: openmp
#    internal_api: openmp
#         version: None
#     num_threads: 12
#
#        filepath: C:\ProgramData\anaconda3\Library\bin\libiomp5md.dll
#          prefix: libiomp
#        user_api: openmp
#    internal_api: openmp
#         version: None
#     num_threads: 12

# %%
Kmeans_ParameterTesting_SSE(pca_df)

# %%
pca_df.dropna(axis = 1, inplace = True)

# %%
pca_df
# Out:
#                                                          PC1       PC2  \
# Communication Services-Communication Services -... -1.393611 -3.317084
# Communication Services-Communication Services -... -0.152787 -1.972161
# Communication Services-Communication Services -... -4.365953 -6.076754
# Communication Services-Communication Services -... -3.200594 -5.707823
# Communication Services-Communication Services -... -2.932753 -7.038817
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -2.911520  4.339023
# Utilities-Utilities - 600886.SH.csv                -2.597226  4.397263
# Utilities-Utilities - 600900.SH.csv                -4.333178  2.550497
# Utilities-Utilities - 600905.SH.csv                -0.790437  2.868300
# Utilities-Utilities - 601985.SH.csv                -2.728036  4.875551
#
#                                                          PC3       PC4  \
# Communication Services-Communication Services -...  1.609912 -0.339521
# Communication Services-Communication Services -...  4.134690 -0.299907
# Communication Services-Communication Services -... -4.213454 -2.709115
# Communication Services-Communication Services -...  1.802459  0.819092
# Communication Services-Communication Services -...  1.167620 -1.555260
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                -0.633838  0.188865
# Utilities-Utilities - 600886.SH.csv                 1.398309  4.433166
# Utilities-Utilities - 600900.SH.csv                 1.069864  2.581114
# Utilities-Utilities - 600905.SH.csv                 2.010651  3.561457
# Utilities-Utilities - 601985.SH.csv                 2.008288  1.807844
#
#                                                          PC5       PC6  \
# Communication Services-Communication Services -...  0.195285  0.633685
# Communication Services-Communication Services -...  0.983255  0.968044
# Communication Services-Communication Services -... -1.117354 -1.347128
# Communication Services-Communication Services -... -0.402213 -0.852906
# Communication Services-Communication Services -...  0.777377 -1.838597
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 3.321757 -2.764405
# Utilities-Utilities - 600886.SH.csv                 1.171467 -1.546731
# Utilities-Utilities - 600900.SH.csv                 0.417694 -1.060023
# Utilities-Utilities - 600905.SH.csv                 0.857934 -0.562986
# Utilities-Utilities - 601985.SH.csv                 2.376284 -0.753135
#
#                                                          PC7       PC8  \
# Communication Services-Communication Services -... -1.087427  1.294273
# Communication Services-Communication Services -... -2.643640 -0.284317
# Communication Services-Communication Services -...  0.756668  3.670884
# Communication Services-Communication Services -... -0.961888  2.574774
# Communication Services-Communication Services -... -0.827694  4.877898
# ...                                                      ...       ...
# Utilities-Utilities - 600803.SH.csv                 0.079118  2.671561
# Utilities-Utilities - 600886.SH.csv                -0.870411  3.189722
# Utilities-Utilities - 600900.SH.csv                -0.143738 -1.161847
# Utilities-Utilities - 600905.SH.csv                -0.995841  3.911186
# Utilities-Utilities - 601985.SH.csv                 0.202076  5.014005
#
#                                                          PC9
# Communication Services-Communication Services -... -0.090013
# Communication Services-Communication Services -... -0.038565
# Communication Services-Communication Services -...  1.783099
# Communication Services-Communication Services -... -0.251432
# Communication Services-Communication Services -...  0.529612
# ...                                                      ...
# Utilities-Utilities - 600803.SH.csv                -1.084160
# Utilities-Utilities - 600886.SH.csv                 0.695800
# Utilities-Utilities - 600900.SH.csv                 0.255208
# Utilities-Utilities - 600905.SH.csv                 0.826512
# Utilities-Utilities - 601985.SH.csv                 0.411284
#
# [297 rows x 9 columns]

# %%
final_kmeans = KMeans(n_clusters = 9, **kmeans_kwargs, random_state= 2023)
final_kmeans.fit(pca_df)
#silhouette_scores['KMeans'] = silhouette_score(pca_df, final_kmeans.labels_)
cluster_results['KMeans'] = final_kmeans.predict(pca_df)

pca_df.plot('PC1', 'PC2', c = final_kmeans.labels_, kind = 'scatter', figsize = (16,8), cmap = 'jet', title = 'K means cluster results for k = 9')
# Out:
# <Axes: title={'center': 'K means cluster results for k = 9'}, xlabel='PC1', ylabel='PC2'>

# %%
def draw_dendrogram(df):
  link = linkage(df, method = 'ward')

  plt.figure(figsize = (16,8))
  plt.title("Dendrogram")
  dendrogram(link, orientation = 'top', distance_sort = 'decreasing', show_leaf_counts = True)

draw_dendrogram(pca_df)

# %%
final_agglo = AgglomerativeClustering(n_clusters = 3)
results = final_agglo.fit_predict(pca_df)

cluster_results['Agglo'] = results

pca_df.plot('PC1', 'PC2', marker = 'o', color = results, kind = 'scatter', cmap='jet', figsize = (16,8))
# Out:
# <Axes: xlabel='PC1', ylabel='PC2'>

# %%
def optimal_epsilon(data):
  plt.figure(figsize=(7,4))
  nn = NearestNeighbors(n_neighbors=2).fit(data)
  distances, idx = nn.kneighbors(data)
  distances = np.sort(distances, axis=0)
  distances = distances[:,1]
  plt.plot(distances, color = 'black')
  plt.title("Sorted euclidean distance to nearest neighbour")
  plt.xlabel("Datapoint")
  plt.ylabel("Euclidean Distance")


optimal_epsilon(pca_df)
plt.axhline(y=8, color='black', linestyle='--')

# %%
def get_dbscan(data, eps, min_samples):
  dbscan = DBSCAN(eps=eps, min_samples=min_samples)
  results = dbscan.fit_predict(data)
  # Plot the cluster results.
  fig, ax = plt.subplots(figsize=(7,4))
  data.plot(x="PC1", y="PC2", kind="scatter", 
  title=f"DBSCAN Cluster Results", c=results, cmap="jet", ax=ax)
  plt.show()

  labels = dbscan.labels_
  # Number of clusters in labels, ignoring noise if present.
  n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
  n_noise_ = list(labels).count(-1)
  print('Estimated number of clusters: %d' % n_clusters_)
  print('Estimated number of noise points: %d' % n_noise_)
  #print("Silhouette Coefficient: %0.3f" % silhouette_score(data, labels))

  return results, labels

#eps = 3 , min_samples = 2 as we want to identify at least a pair of securities in the cluster
dbscan_cluster, labels = get_dbscan(pca_df,15,2)
# Out:
# Estimated number of clusters: 1
# Estimated number of noise points: 0

# %%
cluster_results['DBSCAN'] = dbscan_cluster

# %%
def map_clusters(cluster_result: np.array) -> typing.List[typing.List[str]]:
  grouping = [[] for _ in range(max(cluster_result) + 1)]
  for i, res in enumerate(cluster_result):
    grouping[res].append(pca_df.index[i])


  return grouping

# %%
groups = {}
for algorithm, cluster_result in cluster_results.items():
  groups[algorithm] = map_clusters(cluster_result)
print("Number of clusters:", {k:len(v) for k,v in groups.items()})
print('Example of cluster:', groups['KMeans'][0])
# Out:
# Number of clusters: {'KMeans': 9, 'Agglo': 3, 'DBSCAN': 1}
# Example of cluster: ['Communication Services-Communication Services - 002027.SZ.csv', 'Communication Services-Communication Services - 002555.SZ.csv', 'Communication Services-Communication Services - 300413.SZ.csv', 'Consumer Discretionary-Consumer Discretionary - 300979.SZ.csv', 'Consumer Discretionary-Consumer Discretionary - 600754.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 601888.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 603195.SH.csv', 'Consumer Discretionary-Consumer Discretionary - 603486.SH.csv', 'Consumer Staples-Consumer Staples - 000568.SZ.csv', 'Consumer Staples-Consumer Staples - 000596.SZ.csv', 'Consumer Staples-Consumer Staples - 000858.SZ.csv', 'Consumer Staples-Consumer Staples - 002304.SZ.csv', 'Consumer Staples-Consumer Staples - 002311.SZ.csv', 'Consumer Staples-Consumer Staples - 300957.SZ.csv', 'Consumer Staples-Consumer Staples - 300999.SZ.csv', 'Consumer Staples-Consumer Staples - 600132.SH.csv', 'Consumer Staples-Consumer Staples - 600519.SH.csv', 'Consumer Staples-Consumer Staples - 600600.SH.csv', 'Consumer Staples-Consumer Staples - 600809.SH.csv', 'Consumer Staples-Consumer Staples - 600887.SH.csv', 'Consumer Staples-Consumer Staples - 603288.SH.csv', 'Consumer Staples-Consumer Staples - 603369.SH.csv', 'Consumer Staples-Consumer Staples - 605499.SH.csv', 'Consumer Staples-Consumer Staples - 688363.SH.csv', 'Healthcare-Healthcare - 000661.SZ.csv', 'Healthcare-Healthcare - 000963.SZ.csv', 'Healthcare-Healthcare - 300015.SZ.csv', 'Healthcare-Healthcare - 300896.SZ.csv', 'Healthcare-Healthcare - 600436.SH.csv', 'Healthcare-Healthcare - 600763.SH.csv', 'Industry-Industry - 002120.SZ.csv', 'Industry-Industry - 002352.SZ.csv', 'Industry-Industry - 600009.SH.csv', 'Industry-Industry - 600029.SH.csv', 'Industry-Industry - 600115.SH.csv', 'Industry-Industry - 600233.SH.csv', 'Industry-Industry - 601021.SH.csv', 'Industry-Industry - 601111.SH.csv', 'Industry-Industry - 603899.SH.csv', 'Information Technology-Information Technology - 002410.SZ.csv', 'Information Technology-Information Technology - 002415.SZ.csv', 'Information Technology-Information Technology - 002841.SZ.csv']

# %%
len(groups['DBSCAN'][0])
# Out:
# 297

# %%
'''Getting all pairwise combinations within each cluster for each clustering algorithm'''

def find_pairs(algorithm: str, groups: typing.Dict[str,typing.List[typing.List[str]]]) -> pd.core.series.Series:
    total_pairs = []
    for i in range(len(groups[algorithm])):
        pairs = list(combinations(groups[algorithm][i],2))
        #pairs = list(chain.from_iterable(combos))
        total_pairs += pairs

    print(f"Found {len(total_pairs)} potential pairs")

    total_pairs = pd.Series(total_pairs)
    
    print(total_pairs)
    
    return total_pairs

# %%
total_pairs = find_pairs('KMeans', groups)
# Out:
# Found 8760 potential pairs
# 0       (Communication Services-Communication Services...
# 1       (Communication Services-Communication Services...
# 2       (Communication Services-Communication Services...
# 3       (Communication Services-Communication Services...
# 4       (Communication Services-Communication Services...
#                               ...
# 8755    (Industry-Industry - 603806.SH.csv, Industry-I...
# 8756    (Industry-Industry - 603806.SH.csv, Materials-...
# 8757    (Industry-Industry - 688303.SH.csv, Industry-I...
# 8758    (Industry-Industry - 688303.SH.csv, Materials-...
# 8759    (Industry-Industry - 688599.SH.csv, Materials-...
# Length: 8760, dtype: object

# %%
def find_suitable_pairs(df: pd.DataFrame, pairs: pd.core.series.Series) -> pd.core.frame.DataFrame:
    
    # 1. Statistically significant t-stat from the Engle-Granger test (5% level)
    
    engle_granger_tests = []
    norm_spreads = []

    for pair in pairs: # Test each pair for cointegration

        security_0 = df[pair[0]]
        security_1 = df[pair[1]]
        
        # Get independent and dependent variables
        # for OLS calculation and corresponding
        # pvalue for Engle-Granger tests

        test_0 = ts.coint(security_0, security_1)
        test_1 = ts.coint(security_1, security_0)

        t_stat_0, pvalue_0 = test_0[0], test_0[1]
        t_stat_1, pvalue_1 = test_1[0], test_1[1]

        # Choose smallest t-stat for Engle-Granger Test
        if abs(t_stat_0) < abs(t_stat_1):
            pvalue = pvalue_0
            x = sm.add_constant(np.asarray(security_1))
            y = np.asarray(security_0)
        else:
            pvalue = pvalue_1
            x = sm.add_constant(np.asarray(security_0))
            y = np.asarray(security_1)

        engle_granger_tests.append(pvalue)

        # Get parameters and calculate spread
        model = sm.OLS(y, x)
        result = model.fit()
        alpha, beta = result.params[0], result.params[1]

        spread = y - (alpha + beta*x.T[1])
        norm_spread = (spread - np.mean(spread))/np.std(spread)
        norm_spreads.append(norm_spread)

    # Convert spreads from list to dataframe
    norm_spreads = pd.DataFrame(np.transpose(norm_spreads),
                                index=df.index)

    engle_granger_tests = pd.Series(engle_granger_tests)


    
    # 2.Hurst exponent < 0.5

    hurst_exponents = []

    for col in norm_spreads.columns:

            # Create the range of lag values
            lags = range(2, 100)

            # Calculate the array of the variances of the lagged differences
            diffs = [np.subtract(norm_spreads[col].values[l:], norm_spreads[col].values[:-l]) for l in lags]
            tau = [np.sqrt(np.std(diff)) for diff in diffs]

            # Use a linear fit to estimate the Hurst Exponent
            poly = np.polyfit(np.log(lags), np.log(tau), 1)

            # Get the Hurst exponent from the polyfit output
            hurst_exponents.append(poly[0]*2.0)

    hurst_exponents = pd.Series(hurst_exponents)


    
    # 3. Half-life between [1, 252]
    
    lag = norm_spreads.shift(1)
    lag.loc[lag.index[0]] = lag.loc[lag.index[1]]

    ret = norm_spreads - lag
    lag = sm.add_constant(lag)

    model = sm.OLS(ret, lag)
    result = model.fit()
    half_lives = -np.log(2)/result.params.iloc[1]


    
    # 4. Spread must cross the mean on average 12x per year

    mean = 0
    curr_period = norm_spreads
    next_period = norm_spreads.shift(-1)
    count = (
        ((curr_period >= mean) & (next_period < mean)) |  # Over to under
        ((curr_period < mean) & (next_period >= mean)) |  # Under to over
        (curr_period == mean)
        ).sum()
    trading_year = 252
    avg_cross_count = count/(len(df)/trading_year)

    
    
    # Filtering Pairs

    max_pvalue = 0.05
    max_hurst_exp = 0.5
    max_half_life = 252.0
    min_half_life = 1.0
    min_avg_cross = 12.0

    # Generate summary dataframe of potential trading pairs
    pairs_df = pd.concat([pairs,
                          engle_granger_tests,
                          hurst_exponents,
                          half_lives,
                          avg_cross_count],
                         axis=1)
    pairs_df.columns = ['pair',
                        'pvalue',
                        'hurst_exp',
                        'half_life',
                        'avg_cross_count']
    # Find pairs that meet user defined criteria
    filtered_pairs = pairs_df.loc[
        # Significant Engle-Grange test AND
        (pairs_df['pvalue'] <= max_pvalue) &
        # Mean reverting according to Hurst exponent AND
        (pairs_df['hurst_exp'] < max_hurst_exp) &
        # Half-life above minimum value AND
        # Half-life below maximum value AND
        ((pairs_df['half_life'] >= min_half_life) &
         (pairs_df['half_life'] <= max_half_life)) &
        # Produces sufficient number of trading opportunities
        (pairs_df['avg_cross_count'] >= min_avg_cross)]


    if len(filtered_pairs) == 0:
        print("No tradable pairs.")
    else:
        n_pairs = len(filtered_pairs)
        print(f"{n_pairs} tradable pairs found.")
        print(filtered_pairs)
    
    return pairs_df, filtered_pairs

# %%
pairs_df, filtered_pairs = find_suitable_pairs(df_T.T, total_pairs)
# Out:
# 6485 tradable pairs found.
#                                                    pair        pvalue  \
# 0     (Communication Services-Communication Services...  1.673093e-29
# 2     (Communication Services-Communication Services...  0.000000e+00
# 4     (Communication Services-Communication Services...  1.037380e-19
# 5     (Communication Services-Communication Services...  4.969905e-11
# 6     (Communication Services-Communication Services...  7.538697e-20
# ...                                                 ...           ...
# 8755  (Industry-Industry - 603806.SH.csv, Industry-I...  1.801551e-29
# 8756  (Industry-Industry - 603806.SH.csv, Materials-...  8.249050e-11
# 8757  (Industry-Industry - 688303.SH.csv, Industry-I...  3.371344e-28
# 8758  (Industry-Industry - 688303.SH.csv, Materials-...  2.869351e-28
# 8759  (Industry-Industry - 688599.SH.csv, Materials-...  2.239281e-19
#
#       hurst_exp  half_life  avg_cross_count
# 0      0.001769  13.908661       137.980328
# 2      0.007420  29.384722       136.327869
# 4      0.002863  43.500076       130.544262
# 5     -0.010778  18.510973       135.501639
# 6     -0.000988  15.036805       136.327869
# ...         ...        ...              ...
# 8755   0.022868  10.486870       143.763934
# 8756   0.013029  25.584546       122.281967
# 8757   0.006221  23.789044       117.324590
# 8758   0.006197  22.469523       127.239344
# 8759  -0.001537  17.464179       123.934426
#
# [6485 rows x 5 columns]

# %%
filtered_pairs
# Out:
#                                                    pair        pvalue  \
# 0     (Communication Services-Communication Services...  1.673093e-29
# 2     (Communication Services-Communication Services...  0.000000e+00
# 4     (Communication Services-Communication Services...  1.037380e-19
# 5     (Communication Services-Communication Services...  4.969905e-11
# 6     (Communication Services-Communication Services...  7.538697e-20
# ...                                                 ...           ...
# 8755  (Industry-Industry - 603806.SH.csv, Industry-I...  1.801551e-29
# 8756  (Industry-Industry - 603806.SH.csv, Materials-...  8.249050e-11
# 8757  (Industry-Industry - 688303.SH.csv, Industry-I...  3.371344e-28
# 8758  (Industry-Industry - 688303.SH.csv, Materials-...  2.869351e-28
# 8759  (Industry-Industry - 688599.SH.csv, Materials-...  2.239281e-19
#
#       hurst_exp  half_life  avg_cross_count
# 0      0.001769  13.908661       137.980328
# 2      0.007420  29.384722       136.327869
# 4      0.002863  43.500076       130.544262
# 5     -0.010778  18.510973       135.501639
# 6     -0.000988  15.036805       136.327869
# ...         ...        ...              ...
# 8755   0.022868  10.486870       143.763934
# 8756   0.013029  25.584546       122.281967
# 8757   0.006221  23.789044       117.324590
# 8758   0.006197  22.469523       127.239344
# 8759  -0.001537  17.464179       123.934426
#
# [6485 rows x 5 columns]

# %%
filtered_pairs_dict = {}
filtered_pairs_dict['KMeans'] = filtered_pairs

# %%
pairs_statistic = {}
pairs_statistic['Total possible pairs'] = {'KMeans': 5666}
pairs_statistic['Tradable pairs'] = {'KMeans': 1202}

# %%
pairs_statistic
# Out:
# {'Total possible pairs': {'KMeans': 5666}, 'Tradable pairs': {'KMeans': 1202}}

# %%
algos = list(groups.keys())[1:]
algos
# Out:
# ['Agglo', 'DBSCAN']

# %%
for algo in algos:
    total_pairs = find_pairs(algo, groups)
    pairs_statistic['Total possible pairs'][algo] = len(total_pairs)
    pairs_df, filtered_pairs = find_suitable_pairs(df_T.T, total_pairs)
    pairs_statistic['Tradable pairs'][algo] = len(filtered_pairs)
    filtered_pairs_dict[algo] = filtered_pairs
# Out:
# Found 16716 potential pairs
# 0        (Communication Services-Communication Services...
# 1        (Communication Services-Communication Services...
# 2        (Communication Services-Communication Services...
# 3        (Communication Services-Communication Services...
# 4        (Communication Services-Communication Services...
#                                ...
# 16711    (Utilities-Utilities - 600886.SH.csv, Utilitie...
# 16712    (Utilities-Utilities - 600886.SH.csv, Utilitie...
# 16713    (Utilities-Utilities - 600900.SH.csv, Utilitie...
# 16714    (Utilities-Utilities - 600900.SH.csv, Utilitie...
# 16715    (Utilities-Utilities - 600905.SH.csv, Utilitie...
# Length: 16716, dtype: object
# 7763 tradable pairs found.
#                                                     pair        pvalue  \
# 2      (Communication Services-Communication Services...  1.288764e-28
# 4      (Communication Services-Communication Services...  7.664238e-23
# 5      (Communication Services-Communication Services...  2.154654e-11
# 9      (Communication Services-Communication Services...  2.137285e-10
# 11     (Communication Services-Communication Services...  1.033870e-16
# ...                                                  ...           ...
# 16708  (Utilities-Utilities - 600803.SH.csv, Utilitie...  1.822464e-07
# 16709  (Utilities-Utilities - 600803.SH.csv, Utilitie...  2.164265e-07
# 16710  (Utilities-Utilities - 600886.SH.csv, Utilitie...  8.546709e-09
# 16713  (Utilities-Utilities - 600900.SH.csv, Utilitie...  4.086015e-24
# 16714  (Utilities-Utilities - 600900.SH.csv, Utilitie...  1.897016e-29
#
#        hurst_exp   half_life  avg_cross_count
# 2       0.012161  116.513271       126.413115
# 4       0.002794   22.196031       129.718033
# 5      -0.005183   38.494887       126.413115
# 9      -0.015774   78.464420       143.763934
# 11     -0.007326   32.740956       125.586885
# ...          ...         ...              ...
# 16708  -0.001608   16.142112       118.150820
# 16709   0.000659   15.356394       125.586885
# 16710  -0.018893   48.689516       128.065574
# 16713  -0.004159   35.243598       125.586885
# 16714  -0.002958   45.972522       130.544262
#
# [7763 rows x 5 columns]
# Found 43956 potential pairs
# 0        (Communication Services-Communication Services...
# 1        (Communication Services-Communication Services...
# 2        (Communication Services-Communication Services...
# 3        (Communication Services-Communication Services...
# 4        (Communication Services-Communication Services...
#                                ...
# 43951    (Utilities-Utilities - 600886.SH.csv, Utilitie...
# 43952    (Utilities-Utilities - 600886.SH.csv, Utilitie...
# 43953    (Utilities-Utilities - 600900.SH.csv, Utilitie...
# 43954    (Utilities-Utilities - 600900.SH.csv, Utilitie...
# 43955    (Utilities-Utilities - 600905.SH.csv, Utilitie...
# Length: 43956, dtype: object
# 17266 tradable pairs found.
#                                                     pair        pvalue  \
# 4      (Communication Services-Communication Services...  7.664238e-23
# 6      (Communication Services-Communication Services...  2.154654e-11
# 8      (Communication Services-Communication Services...  7.001650e-29
# 13     (Communication Services-Communication Services...  7.952509e-28
# 20     (Communication Services-Communication Services...  3.675499e-16
# ...                                                  ...           ...
# 43948  (Utilities-Utilities - 600803.SH.csv, Utilitie...  1.822464e-07
# 43949  (Utilities-Utilities - 600803.SH.csv, Utilitie...  2.164265e-07
# 43950  (Utilities-Utilities - 600886.SH.csv, Utilitie...  8.546709e-09
# 43953  (Utilities-Utilities - 600900.SH.csv, Utilitie...  4.086015e-24
# 43954  (Utilities-Utilities - 600900.SH.csv, Utilitie...  1.897016e-29
#
#        hurst_exp   half_life  avg_cross_count
# 4       0.002794   70.191662       129.718033
# 6      -0.005183  131.654998       126.413115
# 8      -0.001202  155.348500       136.327869
# 13     -0.004355   71.756378       116.498361
# 20      0.017057  239.149686       131.370492
# ...          ...         ...              ...
# 43948  -0.001608   50.132087       118.150820
# 43949   0.000659   47.656088       125.586885
# 43950  -0.018893  159.180280       128.065574
# 43953  -0.004159  111.885085       125.586885
# 43954  -0.002958  147.278342       130.544262
#
# [17266 rows x 5 columns]

# %%
import pickle
pickle.dump(filtered_pairs_dict, open('filtered_pairs_dict.pickle', 'wb'))
pickle.dump(pairs_statistic, open('pairs_statistic.pickle', 'wb'))

# %%
test = pickle.load(open('filtered_pairs_dict.pickle', 'rb'))
test
# Out:
# {'KMeans':                                                    pair        pvalue  \
#  0     (Communication Services-Communication Services...  1.673093e-29
#  2     (Communication Services-Communication Services...  0.000000e+00
#  4     (Communication Services-Communication Services...  1.037380e-19
#  5     (Communication Services-Communication Services...  4.969905e-11
#  6     (Communication Services-Communication Services...  7.538697e-20
#  ...                                                 ...           ...
#  8755  (Industry-Industry - 603806.SH.csv, Industry-I...  1.801551e-29
#  8756  (Industry-Industry - 603806.SH.csv, Materials-...  8.249050e-11
#  8757  (Industry-Industry - 688303.SH.csv, Industry-I...  3.371344e-28
#  8758  (Industry-Industry - 688303.SH.csv, Materials-...  2.869351e-28
#  8759  (Industry-Industry - 688599.SH.csv, Materials-...  2.239281e-19
#
#        hurst_exp  half_life  avg_cross_count
#  0      0.001769  13.908661       137.980328
#  2      0.007420  29.384722       136.327869
#  4      0.002863  43.500076       130.544262
#  5     -0.010778  18.510973       135.501639
#  6     -0.000988  15.036805       136.327869
#  ...         ...        ...              ...
#  8755   0.022868  10.486870       143.763934
#  8756   0.013029  25.584546       122.281967
#  8757   0.006221  23.789044       117.324590
#  8758   0.006197  22.469523       127.239344
#  8759  -0.001537  17.464179       123.934426
#
#  [6485 rows x 5 columns],
#  'Agglo':                                                     pair        pvalue  \
#  2      (Communication Services-Communication Services...  1.288764e-28
#  4      (Communication Services-Communication Services...  7.664238e-23
#  5      (Communication Services-Communication Services...  2.154654e-11
#  9      (Communication Services-Communication Services...  2.137285e-10
#  11     (Communication Services-Communication Services...  1.033870e-16
#  ...                                                  ...           ...
#  16708  (Utilities-Utilities - 600803.SH.csv, Utilitie...  1.822464e-07
#  16709  (Utilities-Utilities - 600803.SH.csv, Utilitie...  2.164265e-07
#  16710  (Utilities-Utilities - 600886.SH.csv, Utilitie...  8.546709e-09
#  16713  (Utilities-Utilities - 600900.SH.csv, Utilitie...  4.086015e-24
#  16714  (Utilities-Utilities - 600900.SH.csv, Utilitie...  1.897016e-29
#
#         hurst_exp   half_life  avg_cross_count
#  2       0.012161  116.513271       126.413115
#  4       0.002794   22.196031       129.718033
#  5      -0.005183   38.494887       126.413115
#  9      -0.015774   78.464420       143.763934
#  11     -0.007326   32.740956       125.586885
#  ...          ...         ...              ...
#  16708  -0.001608   16.142112       118.150820
#  16709   0.000659   15.356394       125.586885
#  16710  -0.018893   48.689516       128.065574
#  16713  -0.004159   35.243598       125.586885
#  16714  -0.002958   45.972522       130.544262
#
#  [7763 rows x 5 columns],
#  'DBSCAN':                                                     pair        pvalue  \
#  4      (Communication Services-Communication Services...  7.664238e-23
#  6      (Communication Services-Communication Services...  2.154654e-11
#  8      (Communication Services-Communication Services...  7.001650e-29
#  13     (Communication Services-Communication Services...  7.952509e-28
#  20     (Communication Services-Communication Services...  3.675499e-16
#  ...                                                  ...           ...
#  43948  (Utilities-Utilities - 600803.SH.csv, Utilitie...  1.822464e-07
#  43949  (Utilities-Utilities - 600803.SH.csv, Utilitie...  2.164265e-07
#  43950  (Utilities-Utilities - 600886.SH.csv, Utilitie...  8.546709e-09
#  43953  (Utilities-Utilities - 600900.SH.csv, Utilitie...  4.086015e-24
#  43954  (Utilities-Utilities - 600900.SH.csv, Utilitie...  1.897016e-29
#
#         hurst_exp   half_life  avg_cross_count
#  4       0.002794   70.191662       129.718033
#  6      -0.005183  131.654998       126.413115
#  8      -0.001202  155.348500       136.327869
#  13     -0.004355   71.756378       116.498361
#  20      0.017057  239.149686       131.370492
#  ...          ...         ...              ...
#  43948  -0.001608   50.132087       118.150820
#  43949   0.000659   47.656088       125.586885
#  43950  -0.018893  159.180280       128.065574
#  43953  -0.004159  111.885085       125.586885
#  43954  -0.002958  147.278342       130.544262
#
#  [17266 rows x 5 columns]}

# %%
def test_names(iterable):
    top_path = 'C:/Users/user/OneDrive - National University of Singapore/Documents/GitHub/QF5206_chinamarket/individual_data/'
    all_paths = set()
    dfs = []
    for tup in iterable:
        stock1,stock2 = tup[0].replace('-','/', 1), tup[1].replace('-','/',1)
        path1, path2 = top_path + stock1, top_path + stock2
        all_paths.add((tup[0],path1))
        all_paths.add((tup[1],path2))
    for symbol, path in all_paths:

        df = pd.read_csv(path, parse_dates = ['Date'])
        df['Date'] = df['Date'].apply(lambda x: x.replace(tzinfo = None))
        df = df.set_index("Date", drop=True)
        df[symbol] = df['Returns']
        # Log returns

        dfs.append(df[symbol])
    df = pd.concat(dfs, axis=1)
    df = df[start_test:end_test]
    return df



kmeans_df = test_names(test['KMeans']['pair'])
agglo_df = test_names(test['Agglo']['pair'])
dbscan_df = test_names(test['DBSCAN']['pair'])

# %%
kmeans_df
# Out:
#             Healthcare-Healthcare - 601607.SH.csv  \
# Date
# 2023-01-03                               0.016134
# 2023-01-04                              -0.004979
# 2023-01-05                               0.011580
# 2023-01-06                               0.000548
# 2023-01-09                              -0.000548
# ...                                           ...
# 2023-09-22                               0.009537
# 2023-09-25                               0.003901
# 2023-09-26                              -0.003901
# 2023-09-27                               0.011105
# 2023-09-28                              -0.001658
#
#             Industry-Industry - 601816.SH.csv  \
# Date
# 2023-01-03                          -0.012270
# 2023-01-04                          -0.002060
# 2023-01-05                           0.000000
# 2023-01-06                          -0.004132
# 2023-01-09                           0.028573
# ...                                       ...
# 2023-09-22                           0.001940
# 2023-09-25                          -0.003884
# 2023-09-26                           0.001944
# 2023-09-27                           0.000000
# 2023-09-28                          -0.003891
#
#             Consumer Discretionary-Consumer Discretionary - 600660.SH.csv  \
# Date
# 2023-01-03                                           0.012187
# 2023-01-04                                          -0.012472
# 2023-01-05                                           0.011908
# 2023-01-06                                           0.014550
# 2023-01-09                                          -0.008368
# ...                                                       ...
# 2023-09-22                                           0.010732
# 2023-09-25                                           0.003898
# 2023-09-26                                          -0.018320
# 2023-09-27                                          -0.010355
# 2023-09-28                                          -0.014787
#
#             Consumer Discretionary-Consumer Discretionary - 601888.SH.csv  \
# Date
# 2023-01-03                                          -0.008974
# 2023-01-04                                           0.004706
# 2023-01-05                                           0.048943
# 2023-01-06                                          -0.005460
# 2023-01-09                                           0.004485
# ...                                                       ...
# 2023-09-22                                           0.031129
# 2023-09-25                                          -0.014561
# 2023-09-26                                          -0.008296
# 2023-09-27                                           0.006252
# 2023-09-28                                          -0.014335
#
#             Industry-Industry - 300763.SZ.csv  \
# Date
# 2023-01-03                           0.009177
# 2023-01-04                          -0.052015
# 2023-01-05                           0.023037
# 2023-01-06                           0.034958
# 2023-01-09                          -0.021007
# ...                                       ...
# 2023-09-22                           0.023855
# 2023-09-25                           0.007783
# 2023-09-26                           0.000000
# 2023-09-27                           0.043457
# 2023-09-28                          -0.012279
#
#             Communication Services-Communication Services - 601728.SH.csv  \
# Date
# 2023-01-03                                           0.037475
# 2023-01-04                                           0.006873
# 2023-01-05                                          -0.004577
